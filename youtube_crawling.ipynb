# %%
# !pip install google-api-python-client

# %%
import pandas
from googleapiclient.discovery import build

comments = list()
api_obj = build('youtube', 'v3', developerKey='AIzaSyBgUtL2sIRCAVQxGOuoRC17O_hEsBsLIsI')
response = api_obj.commentThreads().list(part='snippet,replies', videoId='AZxZIUQHx5Q', maxResults=100).execute()

# %%
while response:
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        comments.append([comment['textDisplay'], comment['authorDisplayName'], comment['publishedAt'], comment['likeCount']])
 
        if item['snippet']['totalReplyCount'] > 0:
            for reply_item in item['replies']['comments']:
                reply = reply_item['snippet']
                comments.append([reply['textDisplay'], reply['authorDisplayName'], reply['publishedAt'], reply['likeCount']])
 
    if 'nextPageToken' in response:
        response = api_obj.commentThreads().list(part='snippet,replies', videoId='AZxZIUQHx5Q', pageToken=response['nextPageToken'], maxResults=100).execute()
    else:
        break

# %%
df = pandas.DataFrame(comments)

# %%
cols=['comment', 'author', 'date', 'num_likes']
df.columns=cols

# %%
df
# Out:
#                                                 comment            author  \
# 0     They’re so respectful and so nice..i wanna see...             R Bel
# 1                                                너무 잘생김                천혜
# 2               보고있는 제가 다 흐믓해지는데요ㅎㅎ 좋은 영상 감사합니다 감사합니다 🙇               박박박
# 3                        전교회장이 뭐 저리 섹시해….. 안경 좀 치워보자…..              Ahnu
# 4     Breaking these kids out of Beans and Toast.  W...          gbriank1
# ...                                                 ...               ...
# 9298                                               1등!!    Jeonghyun Moon
# 9299                                       선좋아요&gt;&lt;              깡총드브
# 9300                                                  ?               ᄋᄋᄋ
# 9301                                                  1      chiwoo soung
# 9302                                            와 1등 ㄷㄷ  몰래 현우진 풀커리 타는한석원
#
#                       date  num_likes
# 0     2021-07-02T07:51:21Z          0
# ...
