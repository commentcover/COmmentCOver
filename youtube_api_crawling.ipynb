# %%
import pandas as pd
import numpy as np
from googleapiclient.discovery import build

# %%
api_key = 'AIzaSyD-7FgKYHGy29482PnwTWwLTziHbCCrVZ4'

# %%
video_id = 'dPRtcRwKo-Y'

# %%
comments = list()
api_obj = build('youtube', 'v3', developerKey=api_key)
response = api_obj.commentThreads().list(part='snippet,replies', videoId=video_id, maxResults=100).execute()

# %%
while response:
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        comments.append([comment['textDisplay'], comment['authorDisplayName'], comment['publishedAt'], comment['likeCount']])
 
        if item['snippet']['totalReplyCount'] > 0:
            for reply_item in item['replies']['comments']:
                reply = reply_item['snippet']
                comments.append([reply['textDisplay'], reply['authorDisplayName'], reply['publishedAt'], reply['likeCount']])
 
    if 'nextPageToken' in response:
        response = api_obj.commentThreads().list(part='snippet,replies', videoId=video_id, pageToken=response['nextPageToken'], maxResults=100).execute()
    else:
        break

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.1.1; however, version 21.1.3 is available.
# You should consider upgrading via the 'c:\users\jieun\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.

# %%
df = pd.DataFrame(comments)
df.to_csv('results.csv', header=['comment', 'author', 'date', 'num_likes'], index=None)

# %%
results = pd.read_csv('C:\\Users\\JiEun\\results.csv')
# results = results.drop('Unnamed: 0', axis=1)

results # 최근 날짜순
# Out:
#                                                comment          author  \
# 0                                         (몽환적인 전자 음악)             소테킹
# 1                                              강의기대됩니다      David Park
# 2    요즘 JavaScript에 대한 지식이 부족했는데 마침내 무료이고 목소리 좋은 강의...  ParkChanhyeong
# 3                 좋은 강의 감사합니당 덕분에 여기까지 달려왔어요 ㅠㅠ 성취감 히히              데수
# 4                            준비됐나용?하는데 저도 모르게 네에에엥!!!!       TheBeofas
# ..                                                 ...             ...
# 97                                        목소리가너무좋아요 ㅎㅎ             오지민
# 98                      와!!! 정말 기다렸던 수업이예요!! 신난다!!!! 😃        Grace Ji
# 99                                    헐.. PHP도 해주세요!!!             김성수
# 100                                                있어욤     나만 알고 싶은 공간
# 101                              새로운 자바스크립트!! 정말 땡큡니다.             이창기
#
#                      date  num_likes
# 0    2021-05-21T06:31:35Z          0
# 1    2021-05-04T10:40:38Z          0
# ...

# %%
results.sort_values('num_likes', ascending=False) # 인기 댓글순
# Out:
#                                               comment          author  \
# 68   어떻게 이런 퀄리티와 분량의 강좌들을 돈 안 받고 무료로 배포하시는지.... 감사합니다              UJ
# 81                         ;; 이분 구독자가 이렇게 적은게 이해가안감;;     나만 알고 싶은 공간
# 61  누군가 그렇게 말하더라구요. &#39;dog&#39; = html, &#39;bea...  YeonCheol Jang
# 65                <b>그와중에 배경음악 YouTUbe 최초공개 브금 ㅋㅋ</b>           키시 부계
# 49                           인강들으면서 신나는거 처음이에요 ㅠㅠㅠ😍😍😍       PEARLKITE
# ..                                                ...             ...
# 50                                            인정합니다;;  Life of gureum
# 1                                             강의기대됩니다      David Park
# 53                                        감사합니다 사랑합니다  bum programmer
# 62                                            그저 갬동..          떡볶이싫어요
# 51                                                 ㄹㅇ             김민상
#
#                     date  num_likes
# 68  2019-07-22T14:10:54Z        128
# 81  2018-12-03T07:27:17Z         69
# ...

# %%
## 인기 급상승 동영상 50개 크롤링 -> hot_video_crawling.ipynb
