# %%
#pip install google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in c:\users\jaieun\anaconda3\lib\site-packages (2.1.0)
# Requirement already satisfied: six<2dev,>=1.13.0 in c:\users\jaieun\anaconda3\lib\site-packages (from google-api-python-client) (1.15.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in c:\users\jaieun\anaconda3\lib\site-packages (from google-api-python-client) (0.19.1)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in c:\users\jaieun\anaconda3\lib\site-packages (from google-api-python-client) (3.0.1)
# Requirement already satisfied: google-auth<2dev,>=1.16.0 in c:\users\jaieun\anaconda3\lib\site-packages (from google-api-python-client) (1.28.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\users\jaieun\anaconda3\lib\site-packages (from google-api-python-client) (0.1.0)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in c:\users\jaieun\anaconda3\lib\site-packages (from google-api-python-client) (1.26.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyparsing<3,>=2.4.2 in c:\users\jaieun\anaconda3\lib\site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (2.4.7)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\jaieun\anaconda3\lib\site-packages (from google-auth<2dev,>=1.16.0->google-api-python-client) (4.7.2)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\jaieun\anaconda3\lib\site-packages (from google-auth<2dev,>=1.16.0->google-api-python-client) (50.3.1.post20201107)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jaieun\anaconda3\lib\site-packages (from google-auth<2dev,>=1.16.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\jaieun\anaconda3\lib\site-packages (from google-auth<2dev,>=1.16.0->google-api-python-client) (4.2.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in c:\users\jaieun\anaconda3\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (1.53.0)
# Requirement already satisfied: packaging>=14.3 in c:\users\jaieun\anaconda3\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (20.4)
# Requirement already satisfied: protobuf>=3.12.0 in c:\users\jaieun\anaconda3\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (3.15.7)
# Requirement already satisfied: pytz in c:\users\jaieun\anaconda3\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (2020.1)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\jaieun\anaconda3\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (2.24.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\jaieun\anaconda3\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2dev,>=1.16.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jaieun\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\jaieun\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\jaieun\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jaieun\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client) (2020.6.20)

# %%
import pandas
from googleapiclient.discovery import build

video_id="AZxZIUQHx5Q"
api_key="AIzaSyDrmhserZ-TVaS8hTL0gKjZLFwUQOa_pkM"

# %%
comments = list()
api_obj = build('youtube', 'v3', developerKey=api_key)
response = api_obj.commentThreads().list(part='snippet,replies', videoId=video_id, maxResults=100).execute()

while response:
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        comments.append([comment['textDisplay'], comment['authorDisplayName'], comment['publishedAt'], comment['likeCount']])
 
        if item['snippet']['totalReplyCount'] > 0:
            for reply_item in item['replies']['comments']:
                reply = reply_item['snippet']
                comments.append([reply['textDisplay'], reply['authorDisplayName'], reply['publishedAt'], reply['likeCount']])
 
    if 'nextPageToken' in response:
        response = api_obj.commentThreads().list(part='snippet,replies', videoId=video_id, pageToken=response['nextPageToken'], maxResults=100).execute()
    else:
        break

# %%
df = pandas.DataFrame(comments)
df
# Out:
#                                                       0                 1  \
# 0                                너무 재밌어요~영국남자 승승장구하시길^^               소나무
# 1     확실히 21세기가 되어서야 서구권에서 제3세계 식문화를 모욕하는 것이 잘못됐다는 것...       Frigate4one
# 2                      순대 경상도는 막장에 찍어먹는데 소금찍이랑은 다른 맛이있죠        min y -kim
# 3                       학생회장분 잘생기긴 했는데, 댓글들 너무 오바를.. ㅋㅋ              모두행쇼
# 4                                        학생들 컨텐츠 넘꿀잼쓰..                밥이
# ...                                                 ...               ...
# 9218                                               1등!!    Jeonghyun Moon
# 9219                                       선좋아요&gt;&lt;              깡총드브
# 9220                                                  ?               ᄋᄋᄋ
# 9221                                                  1      chiwoo soung
# 9222                                            와 1등 ㄷㄷ  몰래 현우진 풀커리 타는한석원
#
#                          2  3
# 0     2021-07-02T08:29:40Z  0
# 1     2021-07-02T08:28:41Z  0
# 2     2021-07-02T08:26:42Z  0
# 3     2021-07-02T08:23:50Z  0
# 4     2021-07-02T08:21:27Z  0
# ...                    ... ..
# 9218  2021-06-30T12:39:17Z  0
# 9219  2021-06-30T12:39:16Z  0
# 9220  2021-06-30T12:39:16Z  0
# 9221  2021-06-30T12:39:11Z  5
# 9222  2021-06-30T12:53:16Z  0
#
# [9223 rows x 4 columns]
