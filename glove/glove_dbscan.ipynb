# %% [markdown]
# ##코드 참고 - https://jxnjxn.tistory.com/49

# %%
#!pip install glove_python_binary
# Out:
# Collecting glove_python_binary
#   Downloading glove_python_binary-0.2.0-cp38-cp38-win_amd64.whl (244 kB)
# Requirement already satisfied: scipy in c:\users\jaieun\anaconda3\lib\site-packages (from glove_python_binary) (1.5.2)
# Requirement already satisfied: numpy in c:\users\jaieun\anaconda3\lib\site-packages (from glove_python_binary) (1.19.2)
# Installing collected packages: glove-python-binary
# Successfully installed glove-python-binary-0.2.0

# %%
#pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\users\jaieun\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: beautifulsoup4==4.6.0 in c:\users\jaieun\anaconda3\lib\site-packages (from konlpy) (4.6.0)
# Requirement already satisfied: numpy>=1.6 in c:\users\jaieun\anaconda3\lib\site-packages (from konlpy) (1.19.2)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\jaieun\anaconda3\lib\site-packages (from konlpy) (4.6.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tweepy>=3.7.0 in c:\users\jaieun\anaconda3\lib\site-packages (from konlpy) (3.10.0)
# Requirement already satisfied: colorama in c:\users\jaieun\anaconda3\lib\site-packages (from konlpy) (0.4.4)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\jaieun\anaconda3\lib\site-packages (from konlpy) (1.1.2)
# Requirement already satisfied: six>=1.10.0 in c:\users\jaieun\anaconda3\lib\site-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\jaieun\anaconda3\lib\site-packages (from tweepy>=3.7.0->konlpy) (2.24.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jaieun\anaconda3\lib\site-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\jaieun\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jaieun\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jaieun\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\jaieun\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in c:\users\jaieun\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jaieun\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)

# %%
import numpy as np
import pandas as pd
from glove import Corpus, Glove
import pickle

# %%
data = pd.read_csv('mbig_댓글_라벨_띄어쓰기.csv',index_col=0)
tokens = pd.DataFrame(data['comment'])
tokens
# Out:
#                                                 comment
# 0     이 거 그거 같다 그 분노의 질주 더 익스트림에서 샤를리즈 테론 사이퍼 이 좀비 타...
# 1                           아니 ㅋㅋ 브레이크 등 왜 안 들어오냐고 아 ㅋㅋ
# 2     볼보운전자보다 제가 운전 경력 삼십년 가까이 됩니다그동안 대우차 현대차 쉐보레 차 ...
# 3                                         주차부터 멋지게 하셨네요
# 4                              운전 실력 굳 국기 게양대 파워 클라스 인정
# ...                                                 ...
# 5307                                     자살할 용기면 죽이고 죽지
# 5308                     대한민국 진짜 토 나온 다 어떻게 깨끗한 곳 하나 없냐
# 5309  여자는 군에서 아예 배재시 킵시 다 이런 일 예방하려면 사병이 든 부사관이든 장교든...
# 5310                                      군이나 경이나 ㅈㄹ 같다
# 5311                             국군통수권자의 책임입니다 재앙은 물러나라
#
# [5312 rows x 1 columns]

# %%
from konlpy.tag import Okt
okt = Okt()
#okt.morphs(tokens['comment'][1])

# %%
train_token = []
for i in range(len(tokens)):
  train_token.append(okt.morphs(tokens['comment'][i]))
  #print(i)

# %%
train_token
# Out:
# [['이',
#   '거',
#   '그거',
#   '같다',
#   '그',
#   '분노',
#   '의',
#   '질주',
#   '더',
#   '익스트림',
#   '에서',
#   '샤를',
#   '리즈',
#   '테론',
#   '사이퍼',
#   '이',
#   '좀비',
#   '타임',
#   '하면서',
#   '전부',
#   '다',
#   '폐차',
#   '만들어',
#   '놓은',
#   '거'],
#  ['아니', 'ㅋㅋ', '브레이크', '등', '왜', '안', '들어오냐고', '아', 'ㅋㅋ'],
#  ['볼보',
#   '운전자',
#   '보다',
#   '제',
#   '가',
#   '운전',
#   '경력',
#   '삼',
#   '십년',
#   '가까이',
#   '됩니다',
#   '그동안',
#   '대우',
#   '차',
#   '현대차',
#   '쉐보레',
#   '차',
#   '중형',
#   '급',
#   '신차',
#   '만',
#   '뽑아서',
#   '운전',
#   '해본',
#   '결과',
#   '외제차',
#   '는',
#   '무조건',
#   '걸러',
#   '야',
#   '된다고',
#   '봅니다',
#   '사고',
#   '시',
#   '부품',
#   '비',
#   '인건비',
#   '가',
#   '타',
#   '국산',
#   '차',
#   '에',
#   '비해',
#   '비쌉니다',
#   '물론',
#   '잘',
#   '들',
#   '아시겠지만',
#   '국산',
#   '차는',
#   '해외',
#   '수출',
#   '용',
#   '보다',
#   '헉',
#   '소리',
#   '나오게',
#   '국민',
#   '들',
#   '뒷북',
#   '치',
#   '게',
#   '만드시는',
#   '거',
#   '알거에요',
#   '그래도',
#   '국내',
#   '브랜드',
#   '차량',
#   '이',
#   '써비스',
#   '쎈',
#   '타도',
#   '많고',
#   '부품',
#   '준비',
#   '돼',
#   '있고',
#   '외제차',
#   '보다',
#   '추천',
#   '드립니',
#   '다'],
#  ['주차', '부터', '멋지게', '하셨네요'],
#  ['운전', '실력', '굳', '국기', '게양', '대', '파워', '클라스', '인정'],
#  ['자동', '회피', '로', '트럭', '은', '피', '한', '거', '아닌가'],
#  ['저기', '우리', '동넨데'],
#  ['그래도', '현기', '만', '할까'],
#  ['수동',
#   '타는',
#   '데',
#   '현',
#   '기차',
#   '고',
#   '수입',
#   '차고',
#   '쌍용차',
#   '고',
#   '급발진',
#   '사고',
#   '가',
#   '일어',
#   '나네요',
#   '너무',
#   '무섭다',
#   '이럴',
#   '때',
#   '수동',
#   '짱짱맨'],
#  ['3',
#   '달',
#   '된',
#   '사고',
#   '를',
#   '지금',
#   '엠빅',
#   '이',
#   '올린',
#   '다',
#   '이건',
#   '운전자',
#   '가',
#   '언론',
#   '플레이',
#   '하려는',
#   '거임',
#   '이',
#   '거',
#   '사고',
#   '블랙박스',
#   '풀',
#   '영상',
#   '인데',
#   '들어가서',
#   '댓글',
#   '보셈',
#   '운전자',
#   '가',
#   '실수',
#   '한',
#   '거임',
#   '김여사',
#   '가',
#   '중립',
#   '놨',
#   '다가',
#   '엑셀',
#   '을',
#   '브레이크',
#   '로',
#   '착각',
#   '하고',
#   '엑셀',
#   '밟고',
#   '로',
#   '바꿔서',
#   '차가',
#   '달린',
#   '거임',
#   'ㅋㅋ'],
#  ['안전한', '차', '맞냐'],
#  ['그래서', '예능', '에서', '볼보', '광고', '가', '안', '보였구나'],
#  ['뉴스',
#   '똑띠',
#   '안',
#   '씁니까',
#   '브레이크',
#   '등',
#   '단',
#   '한',
#   '번',
#   '도',
#   '안',
#   '들어오는데',
#   '이',
#   '것',
#   '도',
#   '오',
#   '작',
#   '동',
#   '입',
#   '니까',
#   '브레이크',
#   '등',
#   '이',
#   '캔',
#   '통신',
#   '도',
#   '아니고',
#   '스위치',
#   '라',
#   '밟으면',
#   '들어오는',
#   '게',
#   '정상',
#   '인데',
#   '브레이크',
#   '보조',
#   '등',
#   '브레이크',
#   '등',
#   '다',
#   '안',
#   '들어오는',
#   '게',
#   '말',
#   '이',
#   '됩니까',
#   'ㅡㅡ'],
#  ['2억', '겨우'],
#  ['키', '햐', '급발진', '나면', '고객', '탓', '국내', '나', '국외', '나', 'ㅋㅋ'],
#  ['전기차', '를', '타면', '4226226', '이렇게', '될', '수', '있는', '거', '니까', '어떻게', '탐'],
#  ['근데', '브레이크', '등', '안', '들어온', '거', '같은데'],
#  ['저',
#   '차가',
#   '파킹',
#   '브레이크',
#   '가',
#   '전',
#   '자식',
#   '인지',
#   '아',
#   '날로',
#   '근',
#   '진',
#   '모르겠는데',
#   '아날로그',
#   '는',
#   '에',
#   '놓고',
#   '파킹',
#   '브레이크',
#   '댕',
#   '겨놓고',
#   '사이드',
#   '내리는',
#   '순간',
#   '확',
#   '튀어',
#   '나가면서',
#   '급발진',
#   '하는',
#   '경우',
#   '있긴',
#   '함'],
#  ['전', '자식', '의', '큰', '문제점', '이지'],
#  ['ㅇㅋ', '볼보', '안타', '는', '걸', '로'],
#  ['브레이크', '등', '이', '안', '들어오는데', '아닌가'],
#  ['덤프', '트럭', '타야', '됨', '급발진', '없고', '튼튼하고'],
#  ['안전', '우선', '인', '볼보', '는', '어떻게', '처리', '할지'],
#  ['공포', '의', '19초', '영상', '은', '4분', '26초'],
#  ['중국', '지', '리차', '가', '대', '주주', '로', '되더니', '별', '일이', '다', '일어나는군'],
#  ['차', '이상하면', '바로', '박아', '야', '함', '속도', '붙으면', '끝'],
#  ['엄청나게', '와', '소름', '무섭네요', 'ㅜㅜ'],
#  ['저렇게', '달릴', '때', '사람', '안', '친', '게', '정말', '다행', '이네', '요'],
#  ['와',
#   '다리',
#   '떨려요',
#   '진짜',
#   '무서워',
#   '저런',
#   '상황',
#   '에서',
#   '어떻게',
#   '해야',
#   '하는지',
#   '감도',
#   '안',
#   '잡힌다'],
#  ['처음', '부터', '끝', '까지', '브레끼', '등', '안', '들어', '옴끝'],
#  ['보는', '것', '만으로도', '공포', '네', '요'],
#  ['근',
#   '디',
#   '상',
#   '으로는',
#   '브레이크',
#   '밟힌',
#   '흔적',
#   '이',
#   '안',
#   '보이는',
#   '걸',
#   '로',
#   '보아',
#   '서',
#   '급발진',
#   '인정받긴',
#   '힘들어',
#   '보이네요'],
#  ['결코', '자동', '이', '좋은', '건', '아니다', '수동', '장치', '는', '좀', '살려', '놔라'],
#  ['19초', '전', 'ㄷㄷ'],
#  ['46초', '전', 'ㄷㄷ'],
#  ['ㄷㄷ'],
#  ['짱구',
#   '택시',
#   '편',
#   '에서',
#   '나오는',
#   '하늘',
#   '로',
#   '날아서',
#   '낙하',
#   '상',
#   '펼치고',
#   '떨어지는',
#   '거',
#   '라도',
#   '좀',
#   '만',
#   '들어줬으면',
#   '반',
#   '자율',
#   '주행',
#   '도',
#   '가능한데',
#   '그런',
#   '기능',
#   '하나',
#   '쯤',
#   '넣어주세요',
#   '안전띠',
#   '도',
#   '못',
#   '한',
#   '채',
#   '로',
#   '핸들',
#   '도',
#   '안',
#   '먹고',
#   '얼마나',
#   '무서웠을까',
#   'ㅜㅜ'],
#  ['대한민국',
#   '법',
#   '이',
#   '도대체',
#   '왜',
#   '있는',
#   '거지',
#   '국민',
#   '을',
#   '가장',
#   '먼저',
#   '위해',
#   '야',
#   '하는',
#   '거',
#   '아닌가'],
#  ['아니',
#   '믄',
#   '잔',
#   '투기',
#   '처럼',
#   '비상',
#   '탈출',
#   '버튼',
#   '누르면',
#   '선',
#   '루프',
#   '열리면서',
#   '운전',
#   '석',
#   '시트',
#   '랑',
#   '같이',
#   '하늘',
#   '로',
#   '날려',
#   '보내는',
#   '걸',
#   '달거나'],
#  ['볼보',
#   '여서',
#   '살아있는',
#   '것',
#   '을',
#   '다행',
#   '이라고',
#   '해야',
#   '하나',
#   '와',
#   '볼보',
#   '급발',
#   '진',
#   '입증',
#   '하기',
#   '어렵다는',
#   '데'],
#  ['중국산', '끝'],
#  ['우리',
#   '흉기',
#   '를',
#   '보십시요',
#   '볼보',
#   '양반',
#   'ㅋㅋ',
#   '우리',
#   '는',
#   '이',
#   '걸',
#   '우',
#   '전',
#   '미숙',
#   '이라',
#   '결정',
#   '합니다',
#   '허허',
#   '허'],
#  ['트렁크',
#   '안',
#   '에',
#   '낙하산',
#   '같은',
#   '거',
#   '달',
#   '면',
#   '안',
#   '되나',
#   '그',
#   '어느',
#   '정도',
#   '속도',
#   '에선',
#   '트렁크',
#   '열리고',
#   '펼쳐져서',
#   '감속',
#   '되게'],
#  ['볼보', '좋네', '볼보', '사야', '징'],
#  ['아자', '씨', '저', '영상', '보면서', '그렇게', '밖에', '말씀', '못', '하십니까', '아자', '씨'],
#  ['자율',
#   '주행',
#   '이',
#   '좋은',
#   '것',
#   '만은',
#   '아니야',
#   '내',
#   '가',
#   '제어',
#   '하려',
#   '해도',
#   '안',
#   '되잖아',
#   '앞',
#   '으로는',
#   '이런',
#   '끔찍한',
#   '일',
#   '들',
#   '이',
#   '많을',
#   '것',
#   '이다'],
#  ['행동',
#   '요령',
#   '1',
#   '시동',
#   '을',
#   '끄지',
#   '말기',
#   '핸들',
#   '잠길',
#   '위험',
#   '2',
#   '풋',
#   '브레이크',
#   '를',
#   '꾹',
#   '밟기',
#   '나눠',
#   '밟기',
#   '금지',
#   '3',
#   '기어',
#   '를',
#   '중립',
#   '으로',
#   '바꾼다',
#   '또는',
#   '엔진',
#   '브레이크',
#   '이용',
#   '4',
#   '속도',
#   '가',
#   '줄어들면',
#   '사이드',
#   '브레이크',
#   '올린다',
#   '확',
#   '올리면',
#   '드리프트',
#   '발생',
#   '위험',
#   '5',
#   '최후',
#   '의',
#   '수단',
#   '가드레일',
#   '과',
#   '같은',
#   '주변',
#   '안전한',
#   '지형',
#   '지물',
#   '을',
#   '이용',
#   '해',
#   '벽',
#   '을',
#   '긁으면서',
#   '속도',
#   '를',
#   '줄인',
#   '다',
#   '사전',
#   '에',
#   '풋',
#   '블랙박스',
#   '를',
#   '설치',
#   '한',
#   '다'],
#  ['현대', '기', '아가', '더', '심한데', '답', '이', '없다'],
#  ['이', '사고', '역시', '운전자', '과실', '로', '몰아가겠죠', '늘', '그랬던', '것', '처럼'],
#  ['근데', '브레이크', '는', '왜', '안', '잡냐', '운전', '미숙', '90', '퍼', '이상'],
#  ['브레이크',
#   '등',
#   '불',
#   '들어온',
#   '상태',
#   '인데',
#   '질주',
#   '합',
#   '겁니다',
#   '눈',
#   '을',
#   '크게',
#   '뜨고',
#   '보세요'],
#  ['진짜',
#   '이쯤',
#   '되면',
#   '급발진',
#   '대비',
#   '해서',
#   '차량',
#   '바퀴',
#   '강제',
#   '수동',
#   '탈출',
#   '이나',
#   '강제',
#   '엔진',
#   '폭파',
#   '기능',
#   '이라도',
#   '넣어야',
#   '하는',
#   '게',
#   '아닐까',
#   '싶다'],
#  ['볼보', '이', '제', '중국', '차', '아닌가'],
#  ['내', '가', '전자', '장비', '를', '별로', '안', '좋아하는', '이', '유', '중', '하나', '지'],
#  ['출발', '하자', '말', '자', '사이드', '로', '받아야지'],
#  ['지금',
#   '차가',
#   '로',
#   '체',
#   '이노베이션',
#   '2010',
#   '식',
#   '인데',
#   '저런',
#   '전',
#   '자식',
#   '으로',
#   '된',
#   '차',
#   '의',
#   '오',
#   '작동',
#   '때문',
#   '에',
#   '겁나서',
#   '차',
#   '를',
#   '못',
#   '사겠다',
#   '요즘',
#   '은',
#   '다',
#   '저런',
#   '차',
#   '들',
#   '이',
#   '많아서',
#   '겁난',
#   '다',
#   '겁나'],
#  ['저리',
#   '달리는',
#   '데',
#   '브레이크',
#   '등',
#   '이',
#   '안',
#   '들어',
#   '올',
#   '꼬',
#   'ㅋㅋ',
#   '급발질',
#   '이라',
#   '주장',
#   '하는',
#   '사고',
#   '중',
#   '대부분',
#   '은',
#   '그냥',
#   '운전',
#   '미숙'],
#  ['브레이크',
#   '등',
#   '안',
#   '들어오는데',
#   '급발진',
#   '맞어',
#   '다른',
#   '급발진',
#   '사고',
#   '는',
#   '브레이크',
#   '등',
#   '들어오고도',
#   '급발진',
#   '되드',
#   '만'],
#  ['자동', '시스템', '맹신', '하다', '잘', '못', '되면', '큰', '사고', '로', '이어지더라'],
#  ['뭐',
#   '같은',
#   '나라',
#   '일반인',
#   '보고',
#   '증명',
#   '하란',
#   '다',
#   '결론',
#   '일반인',
#   '이',
#   '백프로',
#   '못',
#   '찾는',
#   '걸',
#   '아',
#   '니깐',
#   '전부',
#   '너',
#   '네',
#   '잘못',
#   '이다',
#   '라고',
#   '암암리',
#   '에',
#   '말',
#   '하는',
#   '논리',
#   '지'],
#  ['저기',
#   '요',
#   '현',
#   '기차',
#   '는',
#   '급발진',
#   '더',
#   '많은데',
#   '그거',
#   '는',
#   '안내',
#   '보내주고',
#   '수입',
#   '차만',
#   'ㅎ',
#   '내보내는',
#   '거',
#   '는',
#   '무슨',
#   '심보',
#   '죠'],
#  ['브레이크',
#   '등',
#   '에',
#   '불',
#   '이',
#   '들어오지',
#   '않았어요',
#   '저렇게',
#   '전',
#   '속력',
#   '내는',
#   '데도',
#   '그냥',
#   '엑셀',
#   '밟고',
#   '있는',
#   '것',
#   '같은데요'],
#  ['뺄',
#   '수',
#   '있다면',
#   '자율',
#   '주행',
#   '등등',
#   '전',
#   '자식',
#   '은',
#   '다',
#   '빼야겠구만',
#   '새',
#   '차',
#   '뽑기',
#   '겁나네'],
#  ['어린이', '보호', '구역', '아닌가', '불법', '주', '정차', '잘', '봤습니다'],
#  ['믿고',
#   '거르',
#   '는',
#   '중국산',
#   '중국',
#   '자',
#   '들어가면',
#   '망한',
#   '다',
#   '롤',
#   '판도',
#   '망조',
#   '들',
#   '음'],
#  ['국회의원', '일이', '아니니', '대충', '넘어가는', '거지', 'ㅋㅋㅋㅋ'],
#  ['장애',
#   '인데',
#   '2억원',
#   '이러니',
#   '기업',
#   '들',
#   '이',
#   '소비자',
#   '를',
#   '우습게',
#   '알',
#   '지',
#   '미국',
#   '처럼',
#   '몇',
#   '백억',
#   '소송',
#   '으로',
#   '징벌',
#   '적',
#   '배상',
#   '을',
#   '하게',
#   '해야',
#   '함',
#   '그나',
#   '자',
#   '나',
#   '급발진',
#   '하면',
#   '그냥',
#   '속도',
#   '붙기',
#   '전',
#   '에',
#   '핸들',
#   '틀어',
#   '어디',
#   '나무',
#   '나',
#   '가로등',
#   '벽',
#   '에',
#   '부딪치는',
#   '게',
#   '날',
#   '듯'],
#  ['브레이크', '등', '안', '들어왔는데', '저', '상황', '에서', '뭘', '작동', '할', '수', '있나'],
#  ['요즘',
#   '나오는',
#   '차',
#   '들',
#   '이',
#   '급발진',
#   '차',
#   '들',
#   '이',
#   '너',
#   '무',
#   '만',
#   '네',
#   '옛날',
#   '차',
#   '들',
#   '은',
#   '이런',
#   '차',
#   '들',
#   '은',
#   '없었는',
#   '대차는',
#   '말뚝',
#   '이',
#   '좋은',
#   '건대',
#   '편리하게만',
#   '듬',
#   '만큼',
#   '오',
#   '작동',
#   '이',
#   '너무',
#   '만',
#   '네',
#   '다',
#   '시',
#   '말뚝',
#   '으로',
#   '갑시다'],
#  ['무섭네요'],
#  ['볼보',
#   '도',
#   '중국',
#   '에',
#   '넘어가니',
#   '저렇게',
#   '되',
#   '네',
#   '우와',
#   '차가',
#   '급발진',
#   '에',
#   '통제',
#   '불능',
#   '상태',
#   '네',
#   '요즘',
#   '차는',
#   '전자',
#   '기',
#   '판이',
#   '제어',
#   '를',
#   '하니',
#   '작은',
#   '불량',
#   '에도',
#   '차가',
#   '먹통',
#   '이',
#   '될',
#   '수',
#   '있지',
#   '그',
#   '에',
#   '반해',
#   '예전',
#   '차는',
#   '기계',
#   '식',
#   '이라',
#   '사람',
#   '이',
#   '급발진',
#   '이',
#   '없었지',
#   '특히',
#   '수동',
#   '은',
#   '급발진',
#   '이라는',
#   '게',
#   '없음'],
#  ['급발진', '아닌', '거', '같은데'],
#  ['이', '와중', '에', '어린이', '보호', '구역', '에', '주차', '해놓네', 'ㅋㅋㅋㅋ'],
#  ['브레이크',
#   '등',
#   '이',
#   '않',
#   '보',
#   '이는',
#   '디',
#   '급발진',
#   '도',
#   '브레킹',
#   '등',
#   '은',
#   '들어와',
#   '야',
#   '유리한',
#   '디글',
#   '고',
#   '불법',
#   '주',
#   '정차',
#   '하셨습니다'],
#  ['브레이크', '등', '이', '안', '들어오는', '데'],
#  ['그',
#   '자율',
#   '시스템',
#   '이란',
#   '것',
#   '이',
#   '컴퓨터',
#   '시스템',
#   '이라서',
#   '오류',
#   '가',
#   '나면',
#   '지',
#   '멋대로',
#   '움직일',
#   '수도',
#   '있다고',
#   '본',
#   '다',
#   '앞',
#   '으로의',
#   '지',
#   '동차',
#   '들',
#   '은',
#   '저런',
#   '경우',
#   '가',
#   '허다',
#   '할',
#   '것',
#   '이라',
#   '본',
#   '다',
#   '컴퓨터',
#   '도',
#   '순서',
#   '에',
#   '맞게',
#   '부팅',
#   '을',
#   '하고',
#   '종료',
#   '를',
#   '해야',
#   '오류',
#   '가',
#   '나',
#   '지',
#   '않는다',
#   '분명히',
#   '저건',
#   '시스템',
#   '오류',
#   '일',
#   '가능성',
#   '이',
#   '높다'],
#  ['걍',
#   '바로',
#   '앞',
#   '에',
#   '차',
#   '박는',
#   '게',
#   '제',
#   '일',
#   '낫',
#   '나',
#   '내',
#   '가',
#   '저래되',
#   '면',
#   '어떻게',
#   '하지'],
#  ['비상',
#   '상황',
#   '시',
#   '강제',
#   '종료',
#   '버튼',
#   '좀',
#   '마련',
#   '해라',
#   '정말',
#   '어',
#   '쩔',
#   '수',
#   '없을',
#   '때',
#   '만',
#   '눌러야',
#   '할',
#   '곳',
#   '에',
#   '넣으면',
#   '헷갈리',
#   '지도',
#   '않고',
#   '좋을',
#   '것',
#   '같은',
#   '데'],
#  ['미쳤냐',
#   '그럼',
#   '더',
#   '대형',
#   '사고',
#   '난다',
#   '자동차',
#   '가',
#   '어떻게',
#   '속력',
#   '이',
#   '붙는지',
#   '어떻게',
#   '감속',
#   '을',
#   '하는',
#   '지도',
#   '모르고',
#   '뭔',
#   '컴퓨터',
#   '도',
#   '아니고',
#   '강제',
#   '종료',
#   '버튼',
#   '이야',
#   'ㅋㅋㅋ'],
#  ['사면', '호구', '되는', '외제차'],
#  ['현기',
#   '도',
#   '저런',
#   '사고',
#   '나면',
#   '그냥',
#   '자',
#   '차',
#   '처리',
#   '하고',
#   '만',
#   '하지',
#   '손해배상',
#   '안',
#   '해줌',
#   '자국',
#   '기업',
#   '인데',
#   '더',
#   '심함'],
#  ['자동차',
#   '가',
#   '편한',
#   '도구',
#   '이',
#   '면서',
#   '자칫하면',
#   '남',
#   '을',
#   '죽일',
#   '수도',
#   '본인',
#   '도',
#   '죽',
#   '을',
#   '수',
#   '있다',
#   '너무',
#   '많은',
#   '편의',
#   '장치',
#   '좋을진',
#   '몰라도',
#   '오',
#   '작동',
#   '하',
#   '면',
#   '죽',
#   '을',
#   '수',
#   '있다'],
#  ['안', '전의', '대명사', 'ㅠㅜ'],
#  ['23년', '경력', 'ㅜㅜ'],
#  ['부상',
#   '당하거나',
#   '사고',
#   '당하게',
#   '되면',
#   '건강한',
#   '사람',
#   '도',
#   '자기',
#   '몸',
#   '의',
#   '기능',
#   '을',
#   '잃게',
#   '된다',
#   '저건',
#   '돈',
#   '으로도',
#   '보상',
#   '안',
#   '된다'],
#  ['볼보', '중국', '차임', 'ㅋㅋㅋㅋㅋㅋ'],
#  ['보기', '만', '해도', '무섭다'],
#  ['ㅋㅋ', '볼보', '도', '옛말', '이네'],
#  ['운전자',
#   '뿐',
#   '만',
#   '아니라',
#   '아무',
#   '상관없는',
#   '주변',
#   '운전자',
#   '나',
#   '보행자',
#   '까지도',
#   '큰일',
#   '날',
#   '수',
#   '있는',
#   '건데',
#   '대책',
#   '이',
#   '필요하네요'],
#  ['볼보', '도', '갔구나'],
#  ['말', '이', '쉽지', '재빠르게', '들이', '박는', '거', '힘듦', 'ㅠ', '아이고'],
#  ['불매운동', '해야', '돼'],
#  ['자동차', '인', '간', '멸종', '프로젝트', '를', '실시', '한', '다쿠', '쿠쿠'],
#  ['남일',
#   '이',
#   '아니라',
#   '차',
#   '있는',
#   '모든',
#   '분들',
#   '남',
#   '의',
#   '차',
#   '타는',
#   '모든',
#   '분들',
#   '물론',
#   '나',
#   '에게도',
#   '일어날',
#   '수',
#   '있는',
#   '일이',
#   '라',
#   '더',
#   '무섭다'],
#  ['볼보', '시리즈', '는', '중국', '생산', '입니다'],
#  ['와',
#   '이런',
#   '거',
#   '보면',
#   '너무',
#   '자동화',
#   '도',
#   '좋고',
#   '편한',
#   '건',
#   '아닌',
#   '듯',
#   '많이',
#   '안',
#   '다치고',
#   '사람',
#   '안',
#   '친',
#   '거만',
#   '해도',
#   '천운',
#   '이다'],
#  ['사람', '12', '주'],
#  ['브레이크',
#   '등',
#   '점',
#   '등',
#   '이',
#   '안',
#   '보이는데',
#   '영상',
#   '에서',
#   '보여지는',
#   '부분',
#   '이',
#   '극히',
#   '일부',
#   '라서',
#   '그런',
#   '가요'],
#  ['자율',
#   '주행',
#   '이',
#   '굳이',
#   '필요한지',
#   '궁굼',
#   '하네요',
#   'ㅋㅋ',
#   '많이',
#   '써',
#   '먹지도',
#   '않은데',
#   '문제',
#   '가',
#   '많네요',
#   '블',
#   '박',
#   '발',
#   '옆',
#   '에도',
#   '설치',
#   '해야',
#   '겠네요',
#   '국산',
#   '이고',
#   '외제',
#   '고',
#   '저런',
#   '건',
#   '일단',
#   '발뺌',
#   '하니까',
#   '요',
#   '하긴',
#   '동영상',
#   '있어도',
#   '인정',
#   '안',
#   '하는',
#   '회사',
#   '도',
#   '있던데',
#   '어떻게',
#   '처리할런',
#   '지'],
#  ['여기',
#   '서',
#   '판교',
#   '처가',
#   '집',
#   '쪽',
#   '인데',
#   '저기',
#   '다리',
#   '만',
#   '지나면',
#   '6',
#   '차선',
#   '인',
#   '가',
#   '8',
#   '차선',
#   '인데',
#   '저렇게',
#   '달릴',
#   '수',
#   '는',
#   '없을',
#   '꺼',
#   '같은',
#   '데'],
#  ['중립', '기어', '박아', '라'],
#  ['스틱', '차가', '답', '이네'],
#  ['그', '안전하다는', '볼보', '도', '저런', '게', '터지노'],
#  ['차', '팔기', '전', '엔', '손님', '팔고', '나면', '호구', '되는', '세상'],
#  ['볼보', '불매', '운동', '해야', '한다'],
#  ['그',
#   '와중',
#   '에',
#   '운전',
#   '잘',
#   '하시네',
#   '사람',
#   '이나',
#   '다른',
#   '차',
#   '나',
#   '지형',
#   '지물',
#   '안',
#   '박고',
#   'ㅎㄷㄷ'],
#  ['볼보',
#   '도',
#   '피',
#   '해갈',
#   '수',
#   '없는',
#   '급발진',
#   '이라니',
#   '무섭다',
#   'ㅠ',
#   '제대로',
#   '된',
#   '보상',
#   '과',
#   '사과',
#   '가',
#   '있길'],
#  ['요즘', '차보', '더', '옛날', '차가', '더', '튼튼하고', '좋은', '듯', '안전하고'],
#  ['볼보', '소비자', '가', '인증', '하라'],
#  ['판교', '네'],
#  ['현대차', '는', '운전자', '미숙', '이고', '외제차', '는', '오', '작동', '이냐'],
#  ['급발진',
#   '아닌',
#   '거',
#   '같은데',
#   '브레이크',
#   '등',
#   '도',
#   '안',
#   '들어',
#   '왔고',
#   '영상',
#   '보니',
#   '기',
#   '어변',
#   '속',
#   '하는',
#   '소리',
#   '들리는데',
#   '피해자',
#   '주장',
#   '은',
#   '가만히',
#   '있었는데',
#   '자동',
#   '으로',
#   '출발',
#   '까지',
#   '했단',
#   '건가'],
#  ['또', '국토부', '와', '볼보', '코리아', '에서', '급발진', '은폐', '하려', '하겠내'],
#  ['브레이크', '등', '안', '들어온', '거', '설명', '부터', '하고', '급발진', '영상', '이라고', '올리든'],
#  ['와', '얼마나', '무서웠을까', 'ㅜㅜ'],
#  ['브레이크', '등', '에', '불', '들어와', '있는', '건가', '요', '그냥', '궁금해서요'],
#  ['사이드',
#   '브레이크',
#   '를',
#   '건',
#   '다',
#   '그래도',
#   '속도',
#   '가',
#   '안',
#   '줄어들면',
#   '시동',
#   '을',
#   '꺼',
#   '버린',
#   '다',
#   '이',
#   '것',
#   '도',
#   '방법',
#   '이라네요',
#   '자동차',
#   '의',
#   '전원',
#   '을',
#   '끄면',
#   '소프트웨어',
#   '가',
#   '무소',
#   '불',
#   '위',
#   '에',
#   '것',
#   '도',
#   '전류',
#   '가',
#   '흘러야',
#   '오',
#   '작동',
#   '이라는',
#   '것',
#   '도',
#   '할',
#   '테',
#   '니'],
#  ['차가', '이상', '작동', '하면', '무조건', '박아', '서', '세워야겠네'],
#  ['핸들', '이', '조작', '되지', '않았다면서', '중앙', '선', '넘어서', '앞차', '를', '피하', '네'],
#  ['볼보',
#   '가',
#   '문제',
#   '가',
#   '아니라',
#   '요새',
#   '신',
#   '기술',
#   '관련',
#   '전자',
#   '제어',
#   '쪽',
#   '이',
#   '많은',
#   '기술',
#   '력',
#   '에',
#   '비해',
#   '가끔',
#   '오류',
#   '가',
#   '생기는',
#   '빈도',
#   '가',
#   '심해지는',
#   '건',
#   '사실',
#   '편의',
#   '는',
#   '좋아졌지만',
#   '목숨',
#   '은',
#   '더',
#   '위험해진',
#   '듯'],
#  ['2억원',
#   '의',
#   '손해배상',
#   '소송',
#   '너무',
#   '착하신',
#   '듯',
#   '20억',
#   '을',
#   '배상',
#   '소송',
#   '해도',
#   '모',
#   '지랄',
#   '판',
#   '에'],
#  ['출고', '될', '때', '페달', '쪽', '카메라', '설치', '의', '무적', '으로', '달아야', '함'],
#  ['근데',
#   '브레이크',
#   '등',
#   '은',
#   '왜',
#   '꺼져',
#   '있나요',
#   '그리고',
#   '보통',
#   '시동',
#   '킬',
#   '때',
#   '브레이크',
#   '밟고',
#   '하지',
#   '않나요'],
#  ['공포', '그', '자', '차였을', '듯', 'ㅜㅜ'],
#  ['브레이크',
#   '등',
#   '이',
#   '들어오지',
#   '않은',
#   '것',
#   '으로',
#   '봐',
#   '서는',
#   '브레이크',
#   '를',
#   '전혀',
#   '밟지',
#   '않은',
#   '듯'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '뚜벅', '이', '생각', '좀', '해봅시다'],
#  ['제발', '전화', '끊고', '운전', '하세요', '제발'],
#  ['죽', '을', '뻔했는데', '2억', '으론', '부족할', '듯'],
#  ['출발',
#   '하기',
#   '전',
#   '에',
#   '브레이크',
#   '등',
#   '불',
#   '들어와',
#   '있다가',
#   '출발',
#   '할',
#   '때',
#   '브레이크',
#   '등',
#   '꺼져',
#   '있는',
#   '거',
#   '같은데'],
#  ['운전자', '는', '에', '놓은', '건가', '요', '였을까요'],
#  ['전자기기', '가', '많이', '들어갈수록', '차는', '문제', '가', '많아진다'],
#  ['외국', '차', '팔이', '들', '도', '현기', '가', '어떻게', '대처', '하는지', '다', '알', '텐데'],
#  ['머선', '129'],
#  ['무섭네요'],
#  ['무섭다'],
#  ['급발진',
#   '이라고',
#   '주장',
#   '하는',
#   '거의',
#   '대부분',
#   '의',
#   '사고',
#   '가',
#   '50',
#   '대',
#   '이상',
#   '운전자',
#   '에게서',
#   '발생',
#   '한다',
#   '멈춰',
#   '있는',
#   '차가',
#   '아무',
#   '이유',
#   '없이',
#   '달려',
#   '나가진',
#   '않는다'],
#  ['그리고',
#   '저',
#   '차량',
#   '은',
#   '차선',
#   '이탈',
#   '방지',
#   '전방',
#   '추돌',
#   '방지',
#   '기능',
#   '이',
#   '있는',
#   '차임',
#   '급',
#   '발진',
#   '중',
#   '에는',
#   '작동',
#   '안',
#   '되서',
#   '전문가',
#   '도',
#   '오',
#   '동작',
#   '말',
#   '하는',
#   '거임'],
#  ['내', '가', '현대', '스마트', '센스', '안', '넣는', '이유'],
#  ['현기',
#   '급발진',
#   '은',
#   '방송',
#   '안',
#   '하고',
#   '외제차',
#   '의심',
#   '사례',
#   '는',
#   '바로',
#   '뉴스',
#   '감',
#   '이구나',
#   'ㅋㅋ'],
#  ['이래서', '블랙박스', '에', '소리', '도', '녹음', '해야', '함'],
#  ['늘',
#   '말',
#   '하',
#   '지만',
#   '갑자기',
#   '저러면',
#   '첨',
#   '에',
#   '인도',
#   '로',
#   '올려서',
#   '박아',
#   '서',
#   '강제',
#   '로',
#   '멈췄으면',
#   '덜',
#   '다쳤을',
#   '건데',
#   '아쉽네요'],
#  ['브레이크', '등', '은', '왜', '안', '들어왔을까요'],
#  ['딱', '봐도', '급발진', '인디', '운전자', '가', '이길', '수', '있을까', 'ㅠㅠ'],
#  ['브레이크', '등', '이', '안', '들어온다'],
#  ['신', '자율', '주행', '서비스', '가', '옛날', '차가', '나은', '듯'],
#  ['근데', '솔직히', '차', '에', '타면은', '안전벨트', '는', '무조건', '해야지'],
#  ['얼마나', '무서웠을까'],
#  ['근데', '브레이크', '등', '이', '안', '들어', '오네요'],
#  ['편집',
#   '이',
#   'ㅠ',
#   '어지러워요',
#   'ㅠ',
#   '한국',
#   '에',
#   '들어온',
#   '이상',
#   '고가',
#   '차량',
#   '도',
#   '현기',
#   '와',
#   '다를',
#   '바',
#   '없다'],
#  ['차주',
#   '분',
#   '이',
#   '뒷',
#   '자리',
#   '에',
#   '탔는데',
#   '저런',
#   '상황',
#   '발생',
#   '되면',
#   '어떻게',
#   '되죠',
#   '사건',
#   '이'],
#  ['자율', '주행', '도', '문제', '가', '많네'],
#  ['볼보', '무섭네요'],
#  ['좋아요', '봇', '돌린', '건가'],
#  ['이', '게', '뭔', '데', '좋아요', '수가', 'ㅋㅋㅋㅋ'],
#  ['수', '동', '차량', '이', '정답'],
#  ['이', '세상', '에', '는', '안전한', '차는', '없다'],
#  ['영상', '보면', '핸들', '조정', '되고', '있잖아요'],
#  ['볼보', '도', '걸러', '야', '겠다'],
#  ['어떡해', '하면', '저렇게', '되나요', '무엇', '을', '만져야', '되는', '건가', '요'],
#  ['주', '정차', '금지', '구역', '아닌가'],
#  ['안', '전', '차량', '으로', '유명한', '볼버', '라', '믿었는데', 'ㅜㅜ'],
#  ['브레이크',
#   '를',
#   '왜',
#   '안',
#   '밟으셨을까요',
#   '브레이크',
#   '등',
#   '은',
#   '오',
#   '작동',
#   '할',
#   '수',
#   '없는',
#   '시스템',
#   '인데'],
#  ['아이고',
#   'ㅜㅜ',
#   '별로',
#   '안',
#   '다치시',
#   '길',
#   '바랬는데',
#   'ㅜㅜ',
#   '비명',
#   '소리',
#   '가',
#   '마음',
#   '이',
#   '너무',
#   '아프다'],
#  ['저', '또한', '같은', '생각', '입니다'],
#  ['언젠가', '차', '를', '사게', '되면', '엑셀', '쪽', '에도', '블랙박스', '를', '설치', '해야겠다'],
#  ['이건', '볼보', '회사', '에서', '책임져야', '한다'],
#  ['불매', '한', '번', '갈까', '요'],
#  ['자', '이제', '볼보', '측', '에서', '차가', '왜', '혼자', '서', '이렇게', '갔는지', '밝혀내세요'],
#  ['별다른',
#   '거',
#   '없고',
#   '안전하다고',
#   '사던데',
#   '볼보',
#   '잔',
#   '고장',
#   '많고',
#   '다른',
#   '나라',
#   '에서는',
#   '할인',
#   '없으면',
#   '안',
#   '사는',
#   '차'],
#  ['볼보', '사면', '안', '되겠네요', '내', '목숨', '소중하니까'],
#  ['볼보', '안전한', '차라', '고', '또', '불티', '나게', '팔리겠군'],
#  ['브레이크', '가', '딱딱해지면서', '밟아도', '안', '밟히고', '브레이크', '등', '이', '안', '들어와요'],
#  ['어', '그러네', '킹리', '적', '갓', '심', '으로', '착각', '하고', '잘못', '밟은', '거', '아니냐'],
#  ['보통',
#   '은',
#   '브레이크',
#   '페달',
#   '에',
#   '스위치',
#   '가',
#   '달려서',
#   '브레이크',
#   '동작',
#   '이랑은',
#   '별개',
#   '로',
#   '페달',
#   '만',
#   '밟혀도',
#   '등',
#   '은',
#   '들어와',
#   '요',
#   '진짜',
#   '재수',
#   '없게',
#   '급발진',
#   '브레이크',
#   '등',
#   '고장',
#   '브레이크',
#   '고장',
#   '삼박자',
#   '가',
#   '동',
#   '시에나',
#   '지',
#   '않는',
#   '이상',
#   '말',
#   '이',
#   '안',
#   '되는',
#   '얘기',
#   '임'],
#  ['딱히',
#   '고',
#   '평가',
#   '될',
#   '차',
#   '브랜드',
#   '도',
#   '아닌데',
#   '이상하게',
#   '한국',
#   '에서',
#   '고',
#   '평가',
#   '된',
#   '브랜드'],
#  ['우리나라',
#   '도',
#   '외국',
#   '처럼',
#   '차량',
#   '에',
#   '문제',
#   '가',
#   '생겼을',
#   '시',
#   '에',
#   '차량',
#   '회사',
#   '에서',
#   '확인',
#   '하는',
#   '걸',
#   '로',
#   '해야지',
#   '차',
#   '에',
#   '대해',
#   '소비자',
#   '가',
#   '뭘',
#   '안다고',
#   '원인',
#   '규명',
#   '을',
#   '해야',
#   '한다는',
#   '거',
#   '냐',
#   '나',
#   '참',
#   'ㅋㅋㅋㅋㅋㅋㅋ',
#   '어이없어',
#   '아니',
#   '환자',
#   '가',
#   '병원',
#   '가서',
#   '자기',
#   '몸',
#   '진단',
#   '내리라는',
#   '거',
#   '랑',
#   '똑같은',
#   '거',
#   '잖아'],
#  ['제아',
#   '무리',
#   '안전',
#   '의',
#   '볼보',
#   '라도',
#   '전자',
#   '장치',
#   '앞',
#   '에',
#   '선',
#   '피',
#   '할',
#   '수',
#   '없죠',
#   '아날로그',
#   '차가',
#   '아닌',
#   '이상',
#   '생',
#   '갈',
#   '수',
#   '밖에',
#   '없을',
#   '겁니다'],
#  ['그러고',
#   '보면',
#   '전',
#   '세계',
#   '모든',
#   '자동차',
#   '의',
#   '문제',
#   '인',
#   '듯',
#   '합니다',
#   '전자',
#   '장비',
#   '의',
#   '오류',
#   '무섭네요'],
#  ['뭘', '까', '정말'],
#  ['기계', '가', '인간', '을', '지배', '할', '날', '이', '얼마', '안', '남았다'],
#  ['ㅇㅈ'],
#  ['보기', '만', '해도', '무서운데', '저', '분', '공포', '가', '엄청나게'],
#  ['핸들', '조작', '안', '됐다면서', '블박', '에선', '잘', '되는', '거', '같은데'],
#  ['시동', '꺼야', '합니다'],
#  ['그', '와중', '에', '주', '정차', '금지', '구역', '에', '주차', '해', '놓으셨네'],
#  ['디지털', '방식', '으로', '많이', '변하면서', '요즘', '급발진', '이', '많이', '생긴는', '듯'],
#  ['저', '정도', '면', '대처', '엄청', '잘한', '거임', '무섭네', '저', '차'],
#  ['궁금한', '게', '급발진', '하면', '기', '어', '중립', '에', '놓으면', '되는', '거', '아니여'],
#  ['얼마나', '무서웠을까요', 'ㅠ'],
#  ['너무', '무서웠겠다', 'ㅠㅠㅠㅠㅠㅠ'],
#  ['그냥',
#   '여성',
#   '분',
#   '목소리',
#   '만',
#   '들어',
#   '봐도',
#   '당시',
#   '심리',
#   '상태',
#   '가',
#   '얼마나',
#   '공포',
#   '에',
#   '질렸는지',
#   '느껴집니다',
#   'ㅠㅠ'],
#  ['자동차', '에', '전자', '장치', '가', '너무', '많이', '들어가도', '요즘', '문제', '가', '많음'],
#  ['한국', '법', '은', '개인', '보다', '기업', '에게', '유리하게', '만들어짐'],
#  ['영상', '중간', '에', '분당', '판교', '청소년', '수련', '관', '이라고', '나오잖아요'],
#  ['안전',
#   '을',
#   '철학',
#   '으로',
#   '생각',
#   '하는',
#   '볼보',
#   '는',
#   '사고',
#   '가',
#   '나면',
#   '원인',
#   '을',
#   '찾을려고',
#   '전문가',
#   '를',
#   '투입',
#   '시킨다는데',
#   '한국',
#   '은',
#   '제외',
#   '인',
#   '가벼'],
#  ['피해자',
#   '라고',
#   '주장',
#   '하는',
#   '사람',
#   '이',
#   '주차',
#   '한',
#   '곳',
#   '주',
#   '정차',
#   '금지',
#   '구역',
#   '아닌가요',
#   '저렇게',
#   '법',
#   '을',
#   '어',
#   '기고',
#   '교통',
#   '혼란',
#   '을',
#   '초래',
#   '하니',
#   '귀신',
#   '이',
#   '견인',
#   '해가지요'],
#  ['불법', '주차', '딱지', '는', '끊었', '남'],
#  ['현대', '친구', '생겼네', 'ㅎㅎ'],
#  ['애매하군'],
#  ['통화',
#   '중',
#   '에',
#   '뭔가',
#   '내려가는',
#   '소리',
#   '딱',
#   '들리더니',
#   '그',
#   '때',
#   '부터',
#   '차가',
#   '달리',
#   '네',
#   '전체',
#   '상황',
#   '을',
#   '보고',
#   '싶은데',
#   '편집',
#   '된',
#   '영상',
#   '으로',
#   '툭툭',
#   '끊어져',
#   '있고',
#   '판단',
#   '할',
#   '수가',
#   '없는',
#   '영상',
#   '인데'],
#  ['확실히', '뭔', '소리', '가', '나긴', '하네요'],
#  ['저건',
#   '연기',
#   '한',
#   '다',
#   '고',
#   '해도',
#   '저리',
#   '할',
#   '수가',
#   '없다',
#   '볼보',
#   '가',
#   '잘못',
#   '한',
#   '듯'],
#  ['많이', '다친', '게', '안쓰러울', '뿐이네요', '언능', '쾌차', '하시길'],
#  ['브레이크', '등', '이', '안', '들어오는데', '어찌', '설명', '해야', '하나'],
#  ['어떡해', '피해자', '분', '진짜', '무서우셨겠다', 'ㅠ'],
#  ['에고',
#   '급발진',
#   '사고',
#   '는',
#   '안타깝지만',
#   '애초',
#   '에',
#   '도로',
#   '에',
#   '주차',
#   '하고',
#   '물건',
#   '사온',
#   '것',
#   '도',
#   '그렇고',
#   '물건',
#   '을',
#   '샀으면',
#   '얼른',
#   '차',
#   '를',
#   '다른',
#   '곳',
#   '으로',
#   '이동',
#   '을',
#   '해야지',
#   '벨트',
#   '도',
#   '안',
#   '메고',
#   '통화',
#   '하고',
#   '있다는',
#   '것',
#   '도',
#   '솔직히',
#   '이해',
#   '가',
#   '안',
#   '가네요'],
#  ['이',
#   '거',
#   '뉴스',
#   '로',
#   '보',
#   '니깐',
#   '출발',
#   '전',
#   '에',
#   '덜컥',
#   '하는',
#   '소리',
#   '나',
#   '는데',
#   '글로브',
#   '박스',
#   '열다',
#   '기',
#   '어',
#   '들어',
#   '가서',
#   '당황',
#   '해가지고',
#   '브레이크',
#   '를',
#   '엑셀',
#   '로',
#   '착각',
#   '하고',
#   '밟은',
#   '거',
#   '로',
#   '얘기',
#   '나오던',
#   '데'],
#  ['이',
#   '게',
#   '진짜',
#   '국민',
#   '의',
#   '생명',
#   '이랑',
#   '직결',
#   '되는',
#   '부분',
#   '인데',
#   '입법',
#   '을',
#   '왜',
#   '안',
#   '하는',
#   '거지',
#   '누구',
#   '든',
#   '발생',
#   '할',
#   '수',
#   '있는',
#   '건데'],
#  ['댓글',
#   '들',
#   '왜',
#   '이래',
#   '반',
#   '자율',
#   '주행',
#   '기능',
#   '이',
#   '오',
#   '작동',
#   '났다',
#   '자',
#   '나',
#   '핸들',
#   '제어',
#   '안',
#   '됐다',
#   '자나요',
#   '전문가',
#   '도',
#   '앞차',
#   '가까워지면',
#   '속도',
#   '줄이거나',
#   '정차',
#   '하는',
#   '기능',
#   '이',
#   '작동',
#   '안',
#   '됬',
#   '다',
#   '중앙',
#   '선도',
#   '넘으면',
#   '안',
#   '되는데',
#   '넘어',
#   '갔다',
#   '말',
#   '하자나',
#   '요',
#   '급발진',
#   '이',
#   '면',
#   '앉자마자',
#   '나갔겠지',
#   '시동',
#   '걸었는데',
#   '브레이크',
#   '에',
#   '발',
#   '안',
#   '올리는',
#   '사람',
#   '도',
#   '있음',
#   '설령',
#   '엑셀',
#   '을',
#   '밟았다',
#   '해도',
#   '운전',
#   '한',
#   '짬바',
#   '가',
#   '있는데',
#   '발',
#   '옮기는',
#   '것',
#   '도',
#   '안',
#   '해봤을까',
#   '엑셀',
#   '밟았다',
#   '뗏다',
#   '하면',
#   '차가',
#   '울렁였겠지',
#   '또',
#   '놀라서',
#   '발',
#   '을',
#   '뗏다',
#   '고',
#   '하면',
#   '속도',
#   '가',
#   '오르는',
#   '건',
#   '어떻게',
#   '설',
#   '명함',
#   '무조건',
#   '여자라서',
#   '잘',
#   '못',
#   '했다',
#   '머',
#   '가리',
#   '비었다',
#   '김',
#   '여사',
#   '다',
#   '이런',
#   '말',
#   '은',
#   '생각',
#   '좀',
#   '하면서',
#   '달자',
#   '물론',
#   '불법',
#   '주',
#   '정차',
#   '는',
#   '잘',
#   '못',
#   '임'],
#  ['사람', '은', '살렸네', '사고', '시', '안전성', '은', '최고', '인', '듯'],
#  ['저럴', '땐', '어떻게', '해야', '하나요', 'ㅠㅠㅠㅠㅠ'],
#  ['남자',
#   '도',
#   '많다',
#   '답답',
#   '아',
#   '찾아봐라',
#   '레이싱',
#   '자격증',
#   '있는',
#   '사람',
#   '들',
#   '도',
#   '겪었던',
#   '게',
#   '급발진',
#   '사고',
#   '다'],
#  ['와', '해도', '해도', '너무', '하네'],
#  ['아',
#   '진짜',
#   '이런',
#   '게',
#   '무슨',
#   '문화',
#   '이고',
#   '축제',
#   '라고',
#   '하',
#   '잔인함',
#   '이',
#   '끝',
#   '이',
#   '없구나'],
#  ['식량',
#   '이',
#   '저',
#   '것',
#   '밖에',
#   '없다면',
#   '먹는',
#   '거가',
#   '지고',
#   '뭐라',
#   '안',
#   '함',
#   '다만',
#   '전통',
#   '이라는',
#   '이',
#   '유로',
#   '몇',
#   '백',
#   '마리',
#   '씩',
#   '잡는다는',
#   '게',
#   '이해',
#   '불가',
#   '임',
#   '고래',
#   '잡는',
#   '방법',
#   '도',
#   '잔인하고',
#   '피바다',
#   '가',
#   '된',
#   '저',
#   '곳',
#   '에서',
#   '울부짖는',
#   '고래',
#   '를',
#   '보면서',
#   '사진',
#   '찍으며',
#   '좋아하는',
#   '저',
#   '사람',
#   '들',
#   '을',
#   '보니',
#   '괴로워',
#   '짐',
#   '이런',
#   '축제',
#   '가',
#   '굳이',
#   '존재',
#   '해야',
#   '하는',
#   '이',
#   '유가',
#   '뭐임'],
#  ['속이', '울렁거려', '불쌍한', '고래', '한', '두', '마리', '도', '아니고'],
#  ['이런', '비인간', '적', '인', '행동', '을', '멈추게', '할', '수', '없을까요'],
#  ['먹고', '살', '수단', '이', '저', '것', '뿐', '이라', '그', '런가'],
#  ['이건', '좀', '심하네'],
#  ['2분', '을', '못', '채우고', '시', '청', '포기'],
#  ['자본주의', '도', '너무', '밝히면', '나쁜', '것임'],
#  ['제발',
#   '죽이',
#   '지',
#   '말아주세요',
#   'ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅜㅜㅜㅜㅜㅜㅜㅜㅜㅜㅜㅜㅜㅜㅜㅜㅜㅜ',
#   '너무',
#   '불쌍해요',
#   'ㅠㅠㅠㅠㅠㅠㅠㅠ'],
#  ['불쌍'],
#  ['저', '게', '사람', '이냐', '짐승', '이지'],
#  ['하뭐야'],
#  ['인간', '자체', '에', '환멸', '이', '난다'],
#  ['인간', '이', '제일', '잔인한', '동물'],
#  ['왜',
#   '저러는',
#   '건지',
#   '이해',
#   '가',
#   '안',
#   '되네',
#   '문화',
#   '고',
#   '뭐',
#   '고',
#   '진짜',
#   '무상식',
#   '이다'],
#  ['진짜', '저건', '너무', '햇', '다', '이건', '처벌', '들어가야', '한다', '진짜'],
#  ['저',
#   '게',
#   '축제',
#   '라고',
#   '사람',
#   '이',
#   '할',
#   '짓',
#   '이',
#   '따로',
#   '있지',
#   '어떻게',
#   '저런',
#   '짓',
#   '을'],
#  ['당장', '이런', '사냥', '은', '중지', '해야', '합니다'],
#  ['축제',
#   '를',
#   '빙자',
#   '한',
#   '학살',
#   '을',
#   '유지',
#   '하고',
#   '있네',
#   '마을',
#   '사람',
#   '들',
#   '이야',
#   '흔',
#   '치',
#   '않은',
#   '즐길',
#   '거리',
#   '로',
#   '보는',
#   '것',
#   '이겠지만',
#   '먹을',
#   '게',
#   '없던',
#   '과거',
#   '와는',
#   '달리',
#   '이',
#   '젠',
#   '먹고',
#   '사니즘',
#   '이',
#   '필요한',
#   '전통',
#   '이',
#   '아닌데',
#   '뭔가',
#   '인간',
#   '의',
#   '이기심',
#   '을',
#   '극적',
#   '으로',
#   '보여주는',
#   '장면'],
#  ['하아',
#   '뭘',
#   '본',
#   '거',
#   '냐',
#   '내',
#   '가',
#   '21',
#   '세기',
#   '에',
#   '저런',
#   '야만',
#   '적',
#   '인',
#   '행위',
#   '를',
#   '축제',
#   '라',
#   '칭',
#   '하다니'],
#  ['인간',
#   '이',
#   '진짜',
#   '어디',
#   '까지',
#   '잔인',
#   '한',
#   '걸까',
#   '어딘가',
#   '에서',
#   '들은',
#   '말',
#   '이',
#   '지구',
#   '에',
#   '필요',
#   '없는',
#   '동물',
#   '은',
#   '인간',
#   '이라고'],
#  ['저', '들', '이', '축제', '라', '하고', '즐기는', '사람', '이', '있으면', '축제', '다'],
#  ['진짜', '사람', '이', '할', '짓', '이', '아니다'],
#  ['아니',
#   '비난',
#   '여론',
#   '이',
#   '생기',
#   '면',
#   '그만둬야지',
#   '그걸',
#   '숨기려',
#   '하면',
#   '어',
#   '떡',
#   '해요'],
#  ['안', '그래도', '멸종위기종', '인데', '너무한다'],
#  ['정말', '안타깝네요'],
#  ['이건', '아니지요'],
#  ['남', '의', '나라', '전통', '을', '무조건', '비난', '하진', '맙시', '다'],
#  ['보호', '한다고', '다', '지키는', '게', '아니구나'],
#  ['이건', '좀', '많이', '심한데'],
#  ['바다', '에', '생명체', '가', '없다면', '바다', '는', '아름답지', '않다'],
#  ['제발', '그만해'],
#  ['같은', '인간', '인', '게', '부끄럽다', '너무', '한', '거', '아닌가', 'ㅜㅜㅜㅜ'],
#  ['사람', '을', '죽이는', '고래', '보다', '고래', '를', '저렇게', '한', '인간', '이', '더', '잔인하다'],
#  ['어이', '가', '없네'],
#  ['너', '혹시', '채식주의자', '야'],
#  ['아니', '왜', '저러는', '거야', '진짜'],
#  ['인간', '이', '없어져야', '지구', '는', '아름답고', '깨끗해진다'],
#  ['먼',
#   '훗날',
#   '인간',
#   '도',
#   '무언가',
#   '에',
#   '의',
#   '해',
#   '처참히',
#   '학살',
#   '되며',
#   '죗값',
#   '치르겠지',
#   '다',
#   '돌고',
#   '도',
#   '는',
#   '거',
#   '니까'],
#  ['진짜', '인간', '이', '미안해'],
#  ['진짜', '왜', '그러는', '거', '예요', 'ㅠㅠ'],
#  ['가슴', '이', '아프다'],
#  ['와', '저건', '사람', '도', '아니다'],
#  ['안타깝네요'],
#  ['저', '로봇', '입고', '스쾃', '하면', '어떤', '기분', '일까'],
#  ['대박', '이러다', '아이언맨', '만드는', '거', '아닌가요'],
#  ['인력',
#   '을',
#   '대체',
#   '하는',
#   '휴먼',
#   '로',
#   '이드',
#   '와',
#   '기계',
#   '의',
#   '중간',
#   '점',
#   '정도',
#   '보이네요'],
#  ['옛날',
#   '에',
#   '세상',
#   '에',
#   '이런',
#   '일이',
#   '에서',
#   '어떤',
#   '아저씨',
#   '가',
#   '공기',
#   '유압',
#   '로봇',
#   '만들어서',
#   '방송',
#   '에',
#   '나온',
#   '적',
#   '있음',
#   '당시',
#   '에',
#   '카이스트',
#   '교수',
#   '들',
#   '하고',
#   '박사',
#   '들',
#   '찾아와서',
#   '기계',
#   '작동',
#   '원리',
#   '배우고',
#   '감'],
#  ['조금',
#   '만',
#   '더',
#   '기술',
#   '발전',
#   '되면',
#   '지체',
#   '장애',
#   '는',
#   '그냥',
#   '눈',
#   '이',
#   '안',
#   '좋으면',
#   '안경',
#   '쓰는',
#   '것',
#   '처럼',
#   '저런',
#   '로봇',
#   '입고',
#   '다니는',
#   '시대',
#   '가',
#   '오겠다'],
#  ['대박', '이네'],
#  ['여우', '각', '시별', '생각나네', '드라마', 'ㅋㅋ'],
#  ['영화', '엣지', '오브', '투모로우', '가', '생각나네'],
#  ['이제', '외계인', '이랑', '톰', '크루즈', '만', '등장', '하면', '끝'],
#  ['스타크래프트', '마린', '이', '현실', '에서', '나오는군'],
#  ['칩',
#   '같은',
#   '걸',
#   '개발',
#   '해서',
#   '장애',
#   '를',
#   '가지',
#   '고',
#   '있으신',
#   '분',
#   '한테',
#   '이식',
#   '해서',
#   '생각',
#   '만으로',
#   '몸',
#   '을',
#   '움직일',
#   '수',
#   '있게',
#   '만들면',
#   '진짜',
#   '좋겟다'],
#  ['팔', '힘', '은', '좋아야겠네'],
#  ['싸울', '때', '주먹', '도', '로봇', '도입', '가능', 'ㅋ'],
#  ['마지막', '너무', '감동', '무방비', '상태', '로', '있다가', '울컥', '했네요', 'ㅜㅜㅜ'],
#  ['대박', '이', '다', '엘리시움', '에', '나오는', '것', '처럼', '생겼네'],
#  ['진짜',
#   '무거운',
#   '거',
#   '운반',
#   '하시거나',
#   '허리',
#   '안',
#   '좋으신',
#   '분',
#   '들',
#   '한테',
#   '진짜',
#   '좋겠다',
#   '꼭',
#   '싸게',
#   '상용',
#   '화',
#   '되길',
#   '바랍니다'],
#  ['구급대원',
#   '소방대',
#   '원',
#   '에게',
#   '보급',
#   '되어',
#   '생명',
#   '을',
#   '살리는',
#   '일',
#   '에도',
#   '많이',
#   '쓰이',
#   '기를'],
#  ['그런데',
#   '이',
#   '진화',
#   '된',
#   '기술',
#   '을',
#   '악용',
#   '하면',
#   '정말',
#   '무',
#   '시',
#   '무시',
#   '할',
#   '듯',
#   'ㄷㄷ'],
#  ['나중',
#   '엔',
#   '진짜',
#   '영화',
#   '처럼',
#   '군인',
#   '들',
#   '이',
#   '입고',
#   '작',
#   '전',
#   '투입',
#   '할',
#   '듯',
#   '요',
#   'ㄷ'],
#  ['입는', '로봇', '뿐', '아니라', '상당한', '광', '배근', '도', '장', '착하셨네요'],
#  ['기술', '력', '좋아진', '세상', '인데', '왜', '대머리', '는', '아직도', '치료', '를', '못', '하지'],
#  ['치료', '와', '창조', '는', '달라', '서'],
#  ['저런', '거', '는', '전쟁', '터', '에', '사용', '되지', '않기를'],
#  ['근데',
#   '저',
#   '기계',
#   '를',
#   '입',
#   '을',
#   '때',
#   '일어나는',
#   '하중',
#   '은',
#   '기계',
#   '무게',
#   '나갈',
#   '거',
#   '같은데'],
#  ['백만이', '면', '진짜', '살', '만', '한', '데'],
#  ['인간',
#   '대신',
#   '일',
#   '하는',
#   '로봇',
#   '보다',
#   '인간',
#   '이',
#   '더',
#   '쉽게',
#   '일',
#   '하게',
#   '보조',
#   '하는',
#   '기계',
#   '쪽',
#   '이',
#   '더',
#   '빨리',
#   '발달',
#   '하겠군요'],
#  ['일', '고', '리즘', '이', '훨씬', '간단할', '테', '니깐', '여'],
#  ['뭔가',
#   '완전',
#   '자동화',
#   '사회',
#   '와',
#   '노동',
#   '사회',
#   '의',
#   '과도',
#   '기적',
#   '인',
#   '물건',
#   '이라는',
#   '생각',
#   '이',
#   '드',
#   '네'],
#  ['터미네이터', '각', '이', '다', '각'],
#  ['나도',
#   '탐',
#   '나는데',
#   '힘',
#   '안',
#   '들고',
#   '일',
#   '하면서',
#   '돈',
#   '벌고',
#   '싶고',
#   '로',
#   '또는',
#   '더',
#   '좋은데',
#   '안',
#   '되는',
#   '게',
#   '현실',
#   '이라'],
#  ['훌륭합니다'],
#  ['집게', '로봇', '준비', '완료'],
#  ['공부', '열심히', '해야지'],
#  ['근데', '전완', '근', '약하면', '무', '쓸', '모', 'ㅠㅠ'],
#  ['하지만',
#   '진화',
#   '된',
#   '기술',
#   '은',
#   '세상',
#   '을',
#   '망치',
#   '기도',
#   '하죠',
#   '무분별',
#   '하게',
#   '저런',
#   '로봇',
#   '의',
#   '힘',
#   '만',
#   '받으면',
#   '인간',
#   '이',
#   '게을러',
#   '질',
#   '수',
#   '있어',
#   '여',
#   '몸',
#   '이',
#   '굳고',
#   '우리',
#   '자제',
#   '하면서',
#   '진화',
#   '된',
#   '기술',
#   '을',
#   '씁시다'],
#  ['안경',
#   '은',
#   '요즘',
#   '기술',
#   '이',
#   '아니죠',
#   '그래도',
#   '1900',
#   '몇십',
#   '년대',
#   '에도',
#   '있었는데',
#   '근데',
#   '렌즈',
#   '는',
#   '신',
#   '기술',
#   '이',
#   '죠',
#   '저',
#   '도',
#   '안경',
#   '은',
#   '잘',
#   '모르지만',
#   '렌즈',
#   '는',
#   '무조건',
#   '많이',
#   '쓰면',
#   '눈',
#   '나빠져요'],
#  ['유튜브',
#   '오',
#   '진짜',
#   '요',
#   '관련',
#   '링크',
#   '좀',
#   '알려주실',
#   '수',
#   '있을까요',
#   '찾아봐도',
#   '그런',
#   '글',
#   '은',
#   '안',
#   '보이네요'],
#  ['안경',
#   '이',
#   '눈',
#   '근육',
#   '을',
#   '퇴화',
#   '시키는',
#   '건',
#   '아니지만',
#   '안경',
#   '쓰다',
#   '보면',
#   '눈',
#   '도',
#   '더',
#   '안',
#   '좋아져요',
#   '렌즈',
#   '는',
#   '더',
#   '더욱이',
#   '고'],
#  ['안경', '이', '눈', '근육', '퇴화', '시키나요'],
#  ['기술', '연구개발', '하시는', '분', '들', '께', '진심', '으로', '감사합니다'],
#  ['팔', '에는', '뭐', '가', '없는데', '원리', '가', '뭐임'],
#  ['진짜', '실용', '성', '대비', '가격', '도', '너무', '좋은', '듯'],
#  ['가격', '도', '싸고', '성능', '은', '좋음'],
#  ['세상', '이', '바뀌고', '있다'],
#  ['나도',
#   '나이',
#   '를',
#   '먹었나',
#   '보다',
#   '전',
#   '신',
#   '마비',
#   '였던',
#   '사람',
#   '이',
#   '걸어오는',
#   '거',
#   '보고',
#   '눈물',
#   '이',
#   '나오네'],
#  ['일거리', '가', '늘어날', '게', '뻔하군'],
#  ['영화',
#   '가',
#   '현실',
#   '로',
#   '되어가고',
#   '있네요',
#   '좋은',
#   '일로',
#   '만',
#   '발전',
#   '되었으면',
#   '좋겠다',
#   '싶네요'],
#  ['몇십', '년', '만', '지나면', '아이언맨', '도', '만드겠', '네', 'ㅋㅋㅋㅋ'],
#  ['지금', '도', '아이언맨', '은', '있는데'],
#  ['우씌', '눈물', '나온', '다', 'ㅠ'],
#  ['새로운', '혁명', '의', '시대', '에', '사는', '게', '아닐까'],
#  ['착용', '시', '다름을', '확', '연히', '느낄', '수가', '있으면', '대', '박', '제품'],
#  ['상', '하차', '좀', '하면', '되겠다'],
#  ['백만',
#   '원',
#   '이면',
#   '주문',
#   '폭주',
#   '할',
#   '듯',
#   '싶은데',
#   '직원',
#   '을',
#   '고용',
#   '해',
#   '더',
#   '한',
#   '달',
#   '에',
#   '200',
#   '인데'],
#  ['백만',
#   '원',
#   '이면',
#   '시',
#   '골',
#   '계신',
#   '부모님',
#   '사드',
#   '리',
#   '고',
#   '싶은데',
#   '과',
#   '연',
#   '언제',
#   '얼마나',
#   '할지',
#   '거의',
#   '모든',
#   '이',
#   '가',
#   '사고',
#   '싶어',
#   '할',
#   '텐데'],
#  ['뽀옇', '게', '보', '여서', '보이지', '도', '않네'],
#  ['오', '조으다'],
#  ['와', '이', '거', '수트', '끝내준다'],
#  ['소중한', '영상', '감사', '드립니다'],
#  ['장비',
#   '를',
#   '끼',
#   '면',
#   '운동',
#   '이',
#   '안',
#   '되죠',
#   'ㅋㅋㅋ',
#   '차라리',
#   '안',
#   '끼',
#   '고',
#   '낮은',
#   '무게',
#   '하는',
#   '게',
#   '나을',
#   '듯',
#   '해',
#   '요'],
#  ['마지막', '함께', '춤추자', '감동', '적이네요'],
#  ['과학', '쿠키', '에서', '봤던', '거', '다'],
#  ['이제', '두', '배', '로', '무거운', '거', '들게', '하겠네', 'ㅋㅋㅋㅋ'],
#  ['자격증', '언제', '딸', '수', '있습니까'],
#  ['택배', '상', '하차', '에', '엄청', '도움', '되겠다'],
#  ['기술', '의', '힘', '과학', '의', '발전', '정말', '좋습니다'],
#  ['빨리',
#   '상용',
#   '화',
#   '되어',
#   '아픔',
#   '이',
#   '있으신',
#   '분',
#   '들',
#   '께',
#   '큰',
#   '힘',
#   '이',
#   '되시길',
#   '바랍니다'],
#  ['저', '도', '쓰고', '싶음'],
#  ['진짜',
#   '저런',
#   '기술',
#   '로봇',
#   '들',
#   '이',
#   '투자',
#   '를',
#   '받아서',
#   '더',
#   '많아',
#   '졌으면',
#   '좋겠습니다'],
#  ['화질', '변경', '못', '하는', '거', '유튜브', '오류', '인', '가요'],
#  ['어릴', '때', '만화책', '으로만', '보던', '게', '일어나', '네', 'ㄷㄷ'],
#  ['저런',
#   '유용하고',
#   '좋은',
#   '기술',
#   '을',
#   '좋은',
#   '곳',
#   '에',
#   '사용',
#   '되어',
#   '기',
#   '쁘',
#   '고',
#   '좋네요'],
#  ['나중', '에', '진짜', '슈트', '입고', '싸우는', '스포츠', '도', '나오겠네'],
#  ['그만큼', '인류', '멸망', '이', '멀지', '않았다는', '거지'],
#  ['마지막', '눈물나네'],
#  ['파이팅'],
#  ['요즘', '날씨', '왜', '이러니', 'ㅠㅠㅠㅠㅠㅠ'],
#  ['숲', '세', '권', '리버', '뷰', '오션', '뷰', '조심해'],
#  ['하늘', '이', '대신', '벌', '하네'],
#  ['백년',
#   '에',
#   '한',
#   '번',
#   '올까',
#   '말까',
#   '한',
#   '게',
#   '매',
#   '해마',
#   '다',
#   '오는',
#   '것',
#   '같다',
#   'ㄹㅇ'],
#  ['우리나라', '도', '불안하다'],
#  ['매번',
#   '이런',
#   '기사',
#   '볼',
#   '때',
#   '마다',
#   '백년',
#   '만에',
#   '한',
#   '번',
#   '올까',
#   '말',
#   '깐',
#   '데',
#   '십',
#   '년',
#   '으로',
#   '바꿔라'],
#  ['시골',
#   '지역',
#   '다니다',
#   '보면',
#   '산',
#   '비탈',
#   '에',
#   '전원주택',
#   '들',
#   '엄청',
#   '많던데',
#   '보기',
#   '에도',
#   '불안혀'],
#  ['껄껄', '껄'],
#  ['한국', '도', '태양광', '설치', '한', '곳', '조심해야', '할', '듯'],
#  ['잘', '가시', '게', '들'],
#  ['무섭네'],
#  ['약하네', 'ㅋㅋ'],
#  ['무섭다',
#   '일본',
#   '정부',
#   '는',
#   '싫어하지만',
#   '자연',
#   '재난',
#   '으로',
#   '어려움',
#   '을',
#   '겪는',
#   '일본',
#   '국민',
#   '들',
#   '에게',
#   '위로',
#   '를',
#   '보낸다'],
#  ['혹시', '나', '구호', '물품', '같은', '거', '보내지', '마라'],
#  ['전쟁',
#   '으로',
#   '많은',
#   '피해자',
#   '를',
#   '만든',
#   '일본',
#   '이',
#   '이',
#   '제',
#   '벌',
#   '을',
#   '받고',
#   '있는',
#   '거',
#   '다',
#   '지진',
#   '해일',
#   '태풍',
#   '모든',
#   '것',
#   '으로',
#   '나라',
#   '는',
#   '멸망',
#   '할',
#   '것',
#   '이다'],
#  ['우리',
#   '도',
#   '긴장',
#   '해야',
#   '한',
#   '다',
#   '더',
#   '더욱',
#   '우리나라',
#   '는',
#   '산지',
#   '가',
#   '많기',
#   '때문',
#   '에',
#   '철저한',
#   '대비',
#   '가',
#   '필요하다'],
#  ['아', 'ㅋㅋ'],
#  ['언제', '다', '치우나'],
#  ['뭐', '가', '문', '젠데'],
#  ['탈출', '이', '아니라', '곧바로', '산', '사태', '에', '쓸려가', '버렸을', '것', '같음'],
#  ['일본',
#   '은',
#   '저',
#   '기회',
#   '가',
#   '일본',
#   '이',
#   '정신',
#   '차릴',
#   '수',
#   '있는',
#   '기회',
#   '가',
#   '됬으면',
#   '좋겠다'],
#  ['앞', '으론', '착하게', '살아라'],
#  ['이런', '일', '더', '생겼으면', '좋겟다'],
#  ['한국', '도', '곧', '장마철', '이라', '준비', '단단히', '해야', '될', '듯', '요'],
#  ['자연', '아', '좀', '만', '더', '힘내라', 'ㅎㅎ'],
#  ['나무', '배어다', '골', '판지', '만들다', '산', '사태', '난', '거임'],
#  ['저희', '집도', '일요일', '에', '그네', '랑', '자전거', '넘어졌어요', 'ㅠㅠ'],
#  ['일본', '은', '진짜', '자연재해', '가', '끊', '임', '이', '없네'],
#  ['머', '어', '때', '자연', '이', '사랑', '하는', '거', '겠지'],
#  ['올림픽', '기간', '동안', '태풍', '도', '올', '거', '같은데'],
#  ['이야', '무슨', '애니메이션', '같네'],
#  ['매',
#   '일',
#   '매일',
#   '우울한',
#   '뉴스',
#   '만',
#   '보다가',
#   '간',
#   '만에',
#   '희소식',
#   '이네',
#   '요',
#   '오늘',
#   '은',
#   '꿀',
#   '잠자야지'],
#  ['자연재해', '가', '무섭네요', '더', '이상', '의', '피해', '가', '없길', '바랍니다'],
#  ['진짜', '몇', '십', '년', '안', '에', '기후', '때문', '에', '지구', '가', '망할까'],
#  ['일본',
#   '은',
#   '굉장히',
#   '오래된',
#   '건물',
#   '이',
#   '많고',
#   '여행',
#   '갈',
#   '때',
#   '마다',
#   '현지',
#   '가이드',
#   '가',
#   '옛',
#   '건물',
#   '에',
#   '자부심',
#   '이',
#   '넘치게',
#   '이야기',
#   '를',
#   '많이',
#   '하더라',
#   '근데',
#   '그럼',
#   '뭐',
#   '해',
#   '다',
#   '무너져',
#   '내리는',
#   '데'],
#  ['지진', '이', '저렇게', '나는데', '버티는', '게', '이', '상한', '거', '아닌가'],
#  ['우리나라', '도', '철저한', '대비', '가', '필요해', '보입니다'],
#  ['진짜', '무슨', '재난', '영화', '의', '한', '장면', '같다'],
#  ['자연재해', '는', '어떻게', '막', '을', '방법', '이', '없는', '거', '같다'],
#  ['한국',
#   '도',
#   '산',
#   '주변',
#   '도로',
#   '옆',
#   '모',
#   '조건',
#   '넝쿨',
#   '뿌리',
#   '나무',
#   '등',
#   '땅',
#   '으로',
#   '깊이',
#   '물이',
#   '지하수',
#   '큰',
#   '땅',
#   '주변',
#   '동굴',
#   '등',
#   '탄광',
#   '근처',
#   '복원',
#   '필수',
#   '땅속',
#   '빈',
#   '공간',
#   '없애',
#   '코',
#   '물석',
#   '수',
#   '공장',
#   '지하수',
#   '그만',
#   '공장',
#   '없애기',
#   '석수',
#   '제조',
#   '군',
#   '나라',
#   '에서만',
#   '제조',
#   '필요시',
#   '전시',
#   '재해',
#   '때',
#   '만',
#   '제',
#   '조',
#   '캠핑',
#   '처러',
#   '조',
#   '나',
#   '대비',
#   '캠핑',
#   '전문',
#   '들',
#   '처럼',
#   '이런',
#   '수상',
#   '구조대',
#   '국',
#   '경찰',
#   '구조대',
#   '들',
#   '나',
#   '같이',
#   '일반인',
#   '들',
#   '도',
#   '배워야',
#   '할',
#   '정보',
#   '시민',
#   '들',
#   '프로그램',
#   '있어도',
#   '보는',
#   '사람',
#   '만',
#   '관심',
#   '있는',
#   '사람',
#   '이제',
#   '구조',
#   '재난',
#   '재해',
#   '전쟁',
#   '시',
#   '가스',
#   '불',
#   '초등',
#   '유치원',
#   '중고',
#   '대학생',
#   '성인',
#   '직장',
#   '들',
#   '도',
#   '이',
#   '제',
#   '전쟁',
#   '예비군',
#   '들',
#   '도',
#   '군인',
#   '도',
#   '의',
#   '무적',
#   '으로',
#   '체육',
#   '시간',
#   '비디오',
#   '등',
#   '훈련',
#   '장',
#   '체험',
#   '1년',
#   '직장',
#   '인들',
#   '학생',
#   '들',
#   '은',
#   '주',
#   '기적',
#   '으로',
#   '비디오',
#   '시청',
#   '을',
#   '주',
#   '1회',
#   '주',
#   '체육',
#   '시간',
#   '마다',
#   '보이는',
#   '포스터',
#   '등',
#   '가르치기'],
#  ['생', '과', '사가', '정말', '간', '발의', '차이네요', '정말', '놀랍습니다'],
#  ['와', '진짜', '인간', '은', '자연', '의', '섭리', '를', '범접', '할', '수가', '없다'],
#  ['일본',
#   '이라는',
#   '나라',
#   '는',
#   '싫지만',
#   '그래도',
#   '죄',
#   '없는',
#   '민간인',
#   '들',
#   '은',
#   '안',
#   '다쳤으면',
#   '좋겠다',
#   '부디',
#   '더',
#   '큰',
#   '피해',
#   '가',
#   '없기를'],
#  ['인명', '피해', '없길', '바랍니다'],
#  ['지구',
#   '가',
#   '계속',
#   '경고',
#   '주고',
#   '있잖아',
#   '진짜',
#   '환경보호',
#   '를',
#   '위해',
#   '전',
#   '세계',
#   '가',
#   '노력',
#   '해야',
#   '함'],
#  ['우리나라', '도', '저렇게', '될', '수', '있을', '거', '같아', '걱정', '이네', '요'],
#  ['저기', '에', '사람', '이', '있었다면', '얼마나', '끔', '찍', '했을까'],
#  ['지구', '온난화', '가', '진짜', '심해지긴', '했구나'],
#  ['자연재해',
#   '에',
#   '피',
#   '해보는',
#   '사람',
#   '은',
#   '거의',
#   '서민',
#   '층일',
#   '듯',
#   '적',
#   '은',
#   '희생',
#   '에',
#   '빠른',
#   '복구',
#   '바랍니다'],
#  ['일본',
#   '은',
#   '일부',
#   '자연재해',
#   '에는',
#   '안전지대',
#   '도',
#   '아닌데',
#   '저렇게',
#   '버텨',
#   '온',
#   '게',
#   '놀랍다'],
#  ['그런', '말', '이', '나옴', '죄', '없는', '민간인', '이', '다치고', '있는데'],
#  ['작년',
#   '에',
#   '이어',
#   '또',
#   '이러는',
#   '건가',
#   '요',
#   'ㅠㅠ',
#   '점점',
#   '기후',
#   '가',
#   '이상해지네요',
#   'ㅠㅠ'],
#  ['하여간',
#   '일본',
#   '만',
#   '나오면',
#   '발작',
#   '이',
#   '네',
#   '이런',
#   '자연재해',
#   '는',
#   '그냥',
#   '나라',
#   '를',
#   '떠나서',
#   '안타까운',
#   '데'],
#  ['그래도',
#   '인간',
#   '적',
#   '으로',
#   '안',
#   '됐다고',
#   '사람',
#   '은',
#   '무사했으면',
#   '좋겠다고',
#   '생각',
#   '한',
#   '내',
#   '가',
#   '너무',
#   '순진했다',
#   '역시',
#   '한국',
#   '소환',
#   '해서',
#   '기',
#   '승전',
#   '한국',
#   '욕',
#   '하는',
#   '거',
#   '보고',
#   '다시',
#   '정신차렸다'],
#  ['그렇다고',
#   '한국',
#   '욕',
#   '하는',
#   '걸',
#   '옹호',
#   '하는',
#   '건',
#   '아닙니다',
#   '둘',
#   '다',
#   '잘',
#   '못',
#   '된',
#   '거',
#   '죠'],
#  ['여기',
#   '도',
#   '기',
#   '승전',
#   '일본',
#   '이라서',
#   '자연재해',
#   '일어나도',
#   '괜찮다고',
#   '하는',
#   '사람',
#   '들',
#   '꽤',
#   '있어요',
#   'ㅋㅋ'],
#  ['우리나라',
#   '도',
#   '작년',
#   '인가',
#   '재작년',
#   '에',
#   '이러지',
#   '않았나',
#   '이번',
#   '해',
#   '는',
#   '무사히',
#   '지나가길'],
#  ['아무리', '빗길이라도', '부산', '버스', '어떻게', '달렸길', '레', '넘어지냐', 'ㄷㄷ'],
#  ['적', '대국', '이지만', '그래도', 'ㅜㅜ', '슬프네요', '삼가', '고인', '의', '명복', '을', '빕니다'],
#  ['우리나라',
#   '도',
#   '태양광',
#   '으로',
#   '멀쩡한',
#   '산',
#   '갈아엎고',
#   '작년',
#   '에',
#   '비',
#   '많이',
#   '왔을',
#   '때',
#   '산',
#   '사태',
#   '증가',
#   '했는데',
#   '올해',
#   '도',
#   '걱정',
#   '이다',
#   'ㅜ'],
#  ['휩쓸려', '죽는', '게', '아니라', '감전', '돼서', '죽겠네'],
#  ['피해자', '가', '없길', '바라며'],
#  ['저런', '게', '가능한', '가', '싶을', '정도', '로', '놀랍다'],
#  ['우리나라',
#   '도',
#   '위험',
#   '지역',
#   '많아요',
#   '자연재해',
#   '앞',
#   '에서',
#   '천벌',
#   '을',
#   '말',
#   '하는',
#   '건',
#   '좀',
#   '누구',
#   '라도',
#   '당할',
#   '수',
#   '있는',
#   '일이',
#   '죠'],
#  ['피해',
#   '는',
#   '있었지만',
#   '그거',
#   '는',
#   '산',
#   '에',
#   '마을',
#   '이',
#   '있진',
#   '않았잖아',
#   '저기',
#   '는',
#   '산',
#   '에',
#   '마을',
#   '이',
#   '있던',
#   '건데',
#   '그게',
#   '휩쓸려',
#   '갔는데'],
#  ['아이고'],
#  ['와', '진짜', '투명', '망토', '가', '나왔네', '도랐네', 'ㅋㅋ'],
#  ['장소', '에', '따라', '바꿔', '입어야', '되는'],
#  ['저', '투', '명', '망토', '원리', '6년', '도', '더', '전', '에', '만화책', '에서', '본', '내용'],
#  ['방탄',
#   '기능',
#   '추가',
#   '에',
#   '가',
#   '벼움',
#   '추가',
#   '면',
#   '쵝',
#   '오',
#   '인데',
#   '다른',
#   '한쪽',
#   '에',
#   '세',
#   'ㅡㅡ',
#   '언',
#   '놈',
#   '주머니',
#   'ㅋ'],
#  ['아군', '끼리', '못', '찾음'],
#  ['자',
#   '이',
#   '제',
#   '투명',
#   '망토',
#   '나왔으니',
#   '순간',
#   '이동',
#   '조',
#   '종반',
#   '지만',
#   '나오면',
#   '되는',
#   '건가'],
#  ['요즘', '이런', '게', '필요하나', '미사일', '핵', '끝나는', '시대', '에', '살', '고', '있는데'],
#  ['이스라엘', '이', '은근', '히', '쌈', '박한', '거', '많이', '만드는', '듯'],
#  ['고스트', '가', '현실', '화', '되다니'],
#  ['스텔스', '방패', '네'],
#  ['그래', '봤자', '도', '입안', '함'],
#  ['제일', '좋은', '것', '은', '저런', '것', '을', '안', '써야겠지요'],
#  ['죽음', '의', '성', '물', '하나', '가', '실제', '로', '존재', '하네', 'ㅎㄷㄷ'],
#  ['마지막', '껀', '진짜', '투명', '망토', '같은', '데'],
#  ['베그', '에', '우선', '도입', '적용'],
#  ['투명', '망토', '대박', '이다'],
#  ['해리포터'],
#  ['도라에몽', '투명', '망토', '가', '만들어지다니'],
#  ['거울',
#   '천',
#   '패',
#   '브릭',
#   '특수',
#   '소재',
#   '로',
#   '개발',
#   '한',
#   '것',
#   '같은데',
#   '가까이',
#   '보면',
#   '티나',
#   '고',
#   '멀리',
#   '서',
#   '보거나',
#   '자세히',
#   '안',
#   '보면',
#   '못',
#   '찾는',
#   '그런',
#   '방식',
#   '같은데',
#   '우리',
#   '가',
#   '먼저',
#   '개발',
#   '해서',
#   '수출',
#   '하자',
#   'ㅋㅋ'],
#  ['신', '박', '한', '세상', '일세', '나도', '한', '장만'],
#  ['배그', '캐쉬', '템', '으로', '나오려', '나', 'ㅋㅋㅋ'],
#  ['이', '거', '반지', '의', '제왕', '에서', '나오는', '엘프', '망토', '자', '나', 'ㅋㅋ'],
#  ['이런', '거', '나오면', '제일', '먼저', '범죄', '집단', '이', '사용', '하겠지'],
#  ['군인', '보호', '가', '곧', '살상', '인데', '건축', '이나', '예술', '에', '쓰여야지요'],
#  ['저', '것', '도', '분명', '같은', '애', '들', '이', '몰래', '빼가겠지'],
#  ['숨바꼭질', '만렙'],
#  ['그래서', '지금', '무력', '으로', '미국', '을', '짓', '밟아', '보겠다고'],
#  ['보급',
#   '화',
#   '됐을',
#   '때',
#   '적의',
#   '지휘',
#   '관',
#   '적',
#   '들이',
#   '안',
#   '보일',
#   '땐',
#   '바위',
#   '를',
#   '쏴라'],
#  ['근데',
#   '진짜',
#   '군복',
#   '이',
#   '숨으면',
#   '잘못',
#   '찾겠',
#   '더',
#   '하',
#   '훈련',
#   '주간',
#   '때',
#   '탄약고',
#   '에',
#   '올라갔는데',
#   '후임',
#   '이',
#   '바위',
#   '산',
#   '쪽',
#   '에서',
#   '뭐',
#   '가',
#   '움직인다고',
#   '해서',
#   '뭔',
#   '개',
#   '소리',
#   '냐',
#   '고',
#   '했는데',
#   '갑자기',
#   '간부',
#   '가',
#   '철수',
#   '이러니라',
#   '10',
#   '명',
#   '정도',
#   '가',
#   '일어나더라',
#   '쓱',
#   '보면',
#   '못',
#   '찾음'],
#  ['위장',
#   '한',
#   '사람',
#   '을',
#   '찾을',
#   '수',
#   '없다고',
#   '요',
#   '수류탄',
#   '몇',
#   '개',
#   '만',
#   '던져',
#   '보세요',
#   '확실합니다'],
#  ['ㅋㅋㅋ',
#   '근데',
#   '우리나라',
#   '개구리',
#   '전투복',
#   '도',
#   '그렇고',
#   '디지털',
#   '군복',
#   '도',
#   '그렇고',
#   '이',
#   '게',
#   '위장',
#   '이',
#   '되긴',
#   '되나',
#   '했는데',
#   '훈련',
#   '나가서',
#   '산',
#   '에',
#   '들어가면',
#   '진짜',
#   '안',
#   '보임',
#   'ㅋㅋㅋㅋ',
#   '구별',
#   '하기',
#   '쉽지',
#   '않더라'],
#  ['디즈니', '마블', '이', '내놓는', '영화', '에', '사실', '미군', '기술', '이', '다', '녹아', '있음'],
#  ['감쪽', '같네', '진짜'],
#  ['소름', '상상', '으로', '생각', '했던', '게', '현실', '이', '됐네'],
#  ['찾기', '가', '너무', '쉬운데', '우리나라', '틀린', '그림', '찾기', '난이도', '를', '모르네', 'ㅎㅎ'],
#  ['와', '기술', '력', '미쳤네'],
#  ['이', '게', '이', '제', '실현', '되고', '뉴스', '로', '도', '나오다니', 'ㄷㄷ'],
#  ['이건', '설마', '겜', '에서만', '봤던', '투명', '망토', '는', '아니', '네', '가', '아니라', '맞네'],
#  ['저', '신소재', '로', '옷', '만들면', '투명인간', '이', '되는군'],
#  ['딱', '보자마자', '다', '찾았는데'],
#  ['마지막', '은', '합성', '임'],
#  ['처음', '부터', '찾아', '버렸자', '너'],
#  ['머글', '이', '마법사', '쌉', '바르겠네'],
#  ['총', '에', '적용', '은', '안', '돼', '나영'],
#  ['꼭',
#   '보면',
#   '군용',
#   '으로',
#   '개발',
#   '한',
#   '제품',
#   '들',
#   '이',
#   '일상',
#   '에서',
#   '더',
#   '잘',
#   '쓰이게',
#   '된다는',
#   '걸',
#   '감안',
#   '하면',
#   '불안한데'],
#  ['이제', '도라에몽', '필요', '없겠네'],
#  ['투명', '망토', '가', '진짜', '있다니'],
#  ['고스트',
#   '클',
#   '로킹',
#   '도',
#   '머',
#   '지',
#   '않았네',
#   '투명',
#   '망토',
#   '까지',
#   '나왔으니',
#   'ㅋㅋ',
#   '이',
#   '제',
#   '보명',
#   '들',
#   '스타',
#   '마린',
#   '처럼',
#   '전투복',
#   '입혀서',
#   '생존',
#   '능력',
#   '높히는',
#   '일만',
#   '남았네'],
#  ['중동', '지방', '파병', '나가서', '활용', '하기에', '좋겠네'],
#  ['저건', '대체', '원리', '가', '뭐임'],
#  ['대박', '이네', '요'],
#  ['솔리드', '스네이크', '는', '아직도', '박스', '쓰고', '다니는데'],
#  ['요즘',
#   '저런',
#   '게',
#   '의미',
#   '있나',
#   '잘',
#   '모르겠으면',
#   '일단',
#   '포탄',
#   '미사일',
#   '겁나',
#   '쏴',
#   '대고',
#   '보는',
#   '시대',
#   '인데'],
#  ['마지막', '에', '군인', '보호', '에만', '쓰시길', '은', '무슨', '의', '미인', '거지'],
#  ['투명', '망토', '사고', '싶다'],
#  ['아직', '은', '티', '가', '난다', 'ㅋㅋㅋ'],
#  ['신기'],
#  ['도라에몽', '의', '투명', '망토', '가', '현실', '화'],
#  ['아닠',
#   'ㅋㅋㅋ',
#   '적',
#   '이랑',
#   '아군',
#   '둘',
#   '다',
#   '쓰면',
#   '쫄아',
#   '서',
#   '바위',
#   '란',
#   '바위',
#   '는',
#   '다',
#   '쏠듯',
#   'ㅋㅋㅋ'],
#  ['왜', '여기', '서', '테라', '브', '금', '이', '나와'],
#  ['점점', '세계', '는', '도라에몽', '을', '향', '하고', '있다'],
#  ['와', '투명', '망토', '가지', '고', '싶다', '헿'],
#  ['갖고', '싶다', 'ㅜㅜ'],
#  ['성범죄', '에', '안', '쓰이게', '생활', '보급', '안', '되도록', '해야', '할', '듯'],
#  ['정말', '대단합니다'],
#  ['이런', '걸', '공개', '하면', '다', '들', '알', '게', '되는', '거', '아닌가'],
#  ['반지', '의', '제왕', '에', '나온', '거', '네'],
#  ['마지막', '대박', '이네'],
#  ['투명', '망', '도', '떨어뜨리면', '어떻게', '찾지'],
#  ['아', '저', '망토', '해리포터', '껀', '데'],
#  ['저런', '걸', '구별', '하려면', '색', '맹인', '사람', '도', '힘들', '것', '다'],
#  ['처음', '것', '들', '은', '걍', '화질', '이', '안', '좋아서', '안', '보이는', '데'],
#  ['대한민국', '군대', '와는', '관계', '없는', '내용', '이네'],
#  ['마지막', '은', '진짜', '인가요'],
#  ['저런', '걸', '로', '군복', '을', '만들면', '되는데'],
#  ['도입', '한다면', '일단', '적', '들', '은', '우릴', '찾는', '것', '자체', '가', '불가능하겠는데'],
#  ['집중', '포격', '만', '안', '받는다면', '좋겠네'],
#  ['덥지는', '않나요'],
#  ['폭격기', '와', '서', '폭', '투하'],
#  ['적', '을', '죽이', '기', '위해', '서', '나를', '보호', '하는', '용도', '로', '나온', '것'],
#  ['외계인', '들', '이', '주는', '기술', '인가'],
#  ['매복', '할', '때', '소대장', '눈', '에', '안', '띄게', '꿀', '잠', '가능', 'ㅋㅋ'],
#  ['방탄복', '에', '방탄', '헬멧', '도', '무조건', '입어야', '하네'],
#  ['소름',
#   '이',
#   '네',
#   'ㅋㅋ',
#   '화면',
#   '에서',
#   '투명',
#   '망토',
#   '라고',
#   '해서',
#   '얼추',
#   '보이는',
#   '거지',
#   '바로',
#   '옆',
#   '에',
#   '있었음',
#   '잘',
#   '모르것',
#   '다',
#   'ㅋㅋ'],
#  ['어떻게', '난', '첫', '번째', '그림', '에서', '한', '번', '에', '다', '찾았지'],
#  ['보자마자', '3', '명', '찾았다', '아직', '멀었다'],
#  ['열', '화상', '카메라', '선', '에서', '정리', '가능'],
#  ['투명', '망토', '가', '현실', '에도', '나왔군', '요', '빨리', '사서', '강화하고', '싶다'],
#  ['드래곤볼', '에', '나오던', '닌', '자', '위장', '술', '이', '생각난다'],
#  ['사람',
#   '을',
#   '요즘',
#   '누가',
#   '찾아',
#   '그냥',
#   '폭탄',
#   '한',
#   '발',
#   '날려주면',
#   '알아서',
#   '죽',
#   '을',
#   '텐데'],
#  ['난', '봣는', '데'],
#  ['그래서',
#   '가격',
#   '은',
#   '이런',
#   '거',
#   '보편화',
#   '가',
#   '안',
#   '되서',
#   '지금',
#   '까지',
#   '조용한',
#   '거',
#   '아님'],
#  ['왜', '나', '는', '보이는', '걸', '가'],
#  ['와', '마지막', '은', '그냥', '해리포터', '아버', '진', '데', 'ㄷㄷㄷㄷ'],
#  ['반지', '의', '제왕', '에', '나오는', '프로도', '망토', '느낌', '이네'],
#  ['반지',
#   '의',
#   '제왕',
#   '두',
#   '개',
#   '의',
#   '탑',
#   '에서',
#   '인가',
#   '호빗',
#   '프로도',
#   '와',
#   '샘',
#   '이',
#   '숨는',
#   '거',
#   '생각나네'],
#  ['우리나라',
#   '군',
#   '복도',
#   '적외선',
#   '저',
#   '감',
#   '처리',
#   '되어',
#   '있는데',
#   '무식한',
#   '다림질',
#   '로',
#   '각',
#   '잡기',
#   '마구잡이',
#   '빨래',
#   '로',
#   '그런',
#   '기능',
#   '따위',
#   '손상',
#   '되어',
#   '없어진지',
#   '오래',
#   '죠'],
#  ['왜',
#   '극',
#   '비',
#   '로',
#   '다루지',
#   '않는',
#   '것',
#   '인가',
#   '어찌',
#   '됐든',
#   '적',
#   '에게',
#   '절대로',
#   '들어가지',
#   '못',
#   '하게',
#   '할',
#   '것'],
#  ['영화', '가', '현실', '로', '와'],
#  ['인간',
#   '을',
#   '효과',
#   '적',
#   '으로',
#   '죽일',
#   '수',
#   '있는',
#   '기술',
#   '이',
#   '하나',
#   '더',
#   '개발',
#   '됐구나'],
#  ['공각기동대', '에', '나오는', '광학', '미', '체', '가', '나오는', '날', '이', '머', '지', '않았구나'],
#  ['와', '투명', '망토', 'ㄷㄷ'],
#  ['다', '보이는데', '유', 'ㅡㅡ'],
#  ['그냥', '대박'],
#  ['도라에몽', '투명', '망토', '빌린', '겨'],
#  ['공', '각', '기동대', '가', '곧', '만들어지겠네', 'ㅎ'],
#  ['이', '거', '그거', '잖아요', '반지', '의', '제왕', '프로', '도망', '토'],
#  ['어차피',
#   '우리나라',
#   '는',
#   '행',
#   '보관',
#   '들',
#   '이',
#   '창고',
#   '에만',
#   '박아',
#   '두고',
#   '검열',
#   '때',
#   '만',
#   '보여줌'],
#  ['저런',
#   '거',
#   '역',
#   '으로',
#   '잡',
#   '을',
#   '염산',
#   '같은',
#   '거',
#   '뿌릴',
#   '수',
#   '있는',
#   '무기',
#   '로',
#   '개발',
#   '해야',
#   '함'],
#  ['복', '붙하지', '마라'],
#  ['개발', '되면', '대박'],
#  ['마지막', '저', '장면', '은', '조작', '이라고', '밝혀졌던', '영상', '클립', '아닌가'],
#  ['다',
#   '들',
#   '뭔',
#   '소리',
#   '하는',
#   '거임',
#   '미국',
#   '에',
#   '이런',
#   '기술',
#   '있다고',
#   '소개',
#   '하는',
#   '영상',
#   '아냐',
#   '한국',
#   '방산',
#   '비리',
#   '가',
#   '여기',
#   '서',
#   '왜',
#   '나옴'],
#  ['세계',
#   '에서',
#   '유일하게',
#   '세금',
#   '횡령',
#   '하는',
#   '공무원',
#   '이',
#   '있는',
#   '나라',
#   '중',
#   '국제',
#   '외',
#   '한국',
#   '인데',
#   'ㅋㅋ'],
#  ['반지',
#   '의',
#   '제왕',
#   '에',
#   '나온',
#   '망토',
#   '같다는',
#   '댓글',
#   '있을',
#   '줄',
#   '알았는데',
#   '없네',
#   '이',
#   '젠',
#   '너무',
#   '고',
#   '전',
#   '영화',
#   '가',
#   '되어',
#   '버린',
#   '건가'],
#  ['내', '옆', '에', '있던', '돌이', '알', '고', '보니', '적군', '이었다'],
#  ['겁나', '잘', '보이는', '데'],
#  ['진짜',
#   '요즘',
#   '기술',
#   '미쳤네',
#   'ㄷㄷㄷ',
#   '게임',
#   '이나',
#   '영화',
#   '에서만',
#   '보던',
#   '게',
#   '현실',
#   '이',
#   '되',
#   '간다'],
#  ['그러면', '뭐', '하냐', '야시', '경이', '없어서', '손전등', '을', '들고', '다니는', '데'],
#  ['한국', '잘', '알'],
#  ['수업', '시간', '에', '덮어', '쓰고', '자면', '모르겟네'],
#  ['원래', '열', '화상', '카메라', '로', '유리나', '천막', '투과', '못', '하는', '데'],
#  ['저런', '거', '없어도', '어차피', '우리나라', '예비군', '은', '잘', '숨음'],
#  ['악의',
#   '적',
#   '으로',
#   '쓰게',
#   '되있다',
#   '이런',
#   '물건',
#   '들',
#   '은',
#   '총',
#   '을',
#   '지키는',
#   '데',
#   '쓰느냐',
#   '죽이는데',
#   '쓰느냐',
#   '쓰는',
#   '사람',
#   '에',
#   '따라',
#   '용도',
#   '가',
#   '바뀌는',
#   '것',
#   '이고',
#   '악의',
#   '적',
#   '으로',
#   '쓰지',
#   '못',
#   '하게',
#   '강력히',
#   '재재해야',
#   '할',
#   '것',
#   '이다'],
#  ['이',
#   '정도',
#   '면',
#   '3',
#   '차',
#   '세계대전',
#   '의',
#   '전투',
#   '는',
#   '얼마나',
#   '무서워질',
#   '까',
#   '그냥',
#   '쉬려고',
#   '돌',
#   '에',
#   '앉으려고',
#   '가',
#   '보니',
#   '갑자기',
#   '적군',
#   '이',
#   '튀어나오면'],
#  ['저',
#   '조그만',
#   '게',
#   '500',
#   '그람',
#   '이',
#   '고',
#   '색깔',
#   '별',
#   '따로',
#   '제작',
#   '이면',
#   '여기저기',
#   '안',
#   '가리고',
#   '임무',
#   '에',
#   '투입',
#   '되는',
#   '보병',
#   '들',
#   '한텐',
#   '그렇고',
#   '저격',
#   '같은',
#   '특수전',
#   '임무',
#   '에만',
#   '쓰일',
#   '듯'],
#  ['어릴',
#   '때',
#   '생각',
#   '하던',
#   '초능력',
#   '3',
#   '대장',
#   '이',
#   '순간',
#   '이동',
#   '시간',
#   '이동',
#   '투명인간',
#   '이었는데',
#   '하나',
#   '성공했네',
#   '고도',
#   '로',
#   '발전',
#   '된',
#   '과학',
#   '은',
#   '마법',
#   '과',
#   '구',
#   '분할',
#   '수',
#   '없다더니',
#   '해리포터',
#   '투명',
#   '망토',
#   '가',
#   '여깄',
#   '네'],
#  ['인간', '의', '진화', '가', '인류', '를', '멸망', '시킨다'],
#  ['그래서', '저걸', '쓰는', '일이', '없으면', '좋겠네요'],
#  ['우리', '는', '진짜', '투명인간', '은', '만들자', '야', '너', '두', '할', '수', '있어'],
#  ['국내',
#   '도입',
#   '안',
#   '됐으면',
#   '좋겠다',
#   '비리',
#   '가',
#   '더',
#   '심해지고',
#   '세금',
#   '낭비',
#   '가',
#   '더',
#   '심해질',
#   '게',
#   '뻔해'],
#  ['지금',
#   '까지',
#   '이런',
#   '기술',
#   '들',
#   '상용',
#   '화',
#   '된',
#   '거',
#   '저',
#   '는',
#   '본',
#   '적',
#   '이',
#   '없네요',
# ...
#  ['학부모', '가', '월급', '을', '준다는', '거', '첨', '알았네'],
#  ['못', '짜른', '거', '에', '요', '안', '짜른', '거', '에요'],
#  ['1억', '이면', '학부모', '얼마', '씩', '내야', '되나'],
#  ['어느',
#   '운동',
#   '이다',
#   '다',
#   '마찬가지',
#   '하여',
#   '간',
#   '감독',
#   '코치',
#   '들',
#   '이',
#   '정상인',
#   '곳',
#   '이',
#   '없지'],
#  ['스포츠',
#   '계',
#   '는',
#   '진짜',
#   '상위',
#   '1',
#   '에',
#   '못',
#   '들면',
#   '운동',
#   '좀',
#   '하는',
#   '아저씨',
#   '로',
#   '늙어가기에',
#   '프로리그',
#   '같은',
#   '곳',
#   '에',
#   '꼭',
#   '들어가야',
#   '하는데',
#   '저',
#   '따구로',
#   '하는',
#   '감독',
#   '은',
#   '참'],
#  ['학원', '스포츠', '는', '프로스포츠', '의', '전', '단계', '가', '될', '수', '없다'],
#  ['저런', '게', '감독', '이냐', '독감', '같은', '놈', '이지'],
#  ['감독', '급여', '를', '교육청', '또는', '학교', '에서', '지급', '을', '해야지'],
#  ['권력', '남용', '은', '절대', '있을', '수', '없는', '일이', '다'],
#  ['그',
#   '성적',
#   '이유',
#   '인천',
#   '에서',
#   '야구',
#   '하는',
#   '사람',
#   '들',
#   '은',
#   '다',
#   '알',
#   '죠',
#   '어디서',
#   '어떻게',
#   '아이',
#   '들',
#   '을',
#   '뽑아오는지',
#   '22년',
#   '도',
#   '들어올',
#   '신입생',
#   '누구',
#   '뽑았는지',
#   '아무',
#   '도',
#   '모릅니',
#   '다',
#   '인천',
#   '에서',
#   '인터뷰',
#   '에서',
#   '자기',
#   '반대',
#   '했던',
#   '학부모',
#   '출신',
#   '중학교',
#   '아이',
#   '들',
#   '1',
#   '명도',
#   '안',
#   '뽑았거든요',
#   '몇',
#   '개',
#   '나',
#   '있다고',
#   '인천',
#   '에서는',
#   '동산',
#   '갈',
#   '생각',
#   '안',
#   '하죠'],
#  ['감독', '만이', '아니라', '교장', '도', '같은', '패거리', '도', '보면', '됨'],
#  ['끝', '까지', '안', '본', '건가', '내용', '이', '해', '를', '못', '한', '거', '같은데'],
#  ['조그마한', '권련', '만', '쥐어지면', '저런다'],
#  ['막줄', '마장', '마장'],
#  ['우리나라', '스포츠', '발전', '이', '없는', '이유'],
#  ['맞', '앙'],
#  ['참', '야구', '란', '알', '수', '없는', '스포츠', '다'],
#  ['뭔가', '명언', '같음', 'ㅋ'],
#  ['자신',
#   '의',
#   '권력',
#   '을',
#   '남용',
#   '하는',
#   '사람',
#   '들',
#   '은',
#   '진짜',
#   '처벌',
#   '엄청',
#   '쎄',
#   '게',
#   '받아야',
#   '하는',
#   '데'],
#  ['구루', '겡'],
#  ['무슨', '감독', '들', '이', '저래'],
#  ['뭐', '든지', '돈', '이', '앞', '에', '있는', '게', '참', '많은', '생각', '이', '듭니', '다'],
#  ['윤리', '가', '무너졌어'],
#  ['이', '걸', '웃어야', '해', '울어야', '혀', 'ㅋㅋㅋㅋㅋㅋ', '큐', 'ㅠㅠ'],
#  ['이', '게', '민주주의', '다'],
#  ['왜', '하나', '도', '안', '불쌍하지'],
#  ['왜', '이러는', '걸까'],
#  ['영국', '코로나', '담당', '이', '라니까', '갑자기', '이', '해', '가', '네', 'ㅋㅋㅋㅋㅋㅋ'],
#  ['아무리',
#   '잘못',
#   '을',
#   '해도',
#   '미워도',
#   '저러면',
#   '되냐',
#   '학교',
#   '에서',
#   '거슬리는',
#   '애',
#   '를',
#   '따시',
#   '키',
#   '고',
#   '때리는',
#   '가해자',
#   '들',
#   '이랑',
#   '뭐',
#   '가',
#   '다름',
#   '저',
#   '들',
#   '도',
#   '저',
#   '정치인',
#   '이',
#   '거슬려서',
#   '저런',
#   '걸',
#   '텐데',
#   '사람',
#   '대',
#   '사람',
#   '이면',
#   '좀',
#   '사람',
#   '답',
#   '게',
#   '행동',
#   '하자',
#   '이성도',
#   '없는',
#   '인간',
#   '이',
#   '어떻게',
#   '인간',
#   '이냐'],
#  ['이건', '계란', '들', '입장', '도', '들어', '봐야', '한다고', '생각', '이', '든다'],
#  ['우리나라', '는', '정치인', '하려면', '뭐', '맞을', '각오', '해야겠네', 'ㅋㅋㅋㅋ'],
#  ['썸네일', '스나이퍼', '엘리트', '인', '줄'],
#  ['롯데', '뭐', '하냐', '유망', '주가', '저기', '있네'],
#  ['셜록', '홈즈', '나라', '런던'],
#  ['맞을', '짓', '을', '했겠지'],
#  ['계란', '이', '아니라', '좀', '더', '확실한', '걸', '로', '갔어야', '하는데', '아깝네요', 'ㅎㅅㅎ'],
#  ['저런', '폭력', '이', '아무', '소용없다지만', '그렇다고', '말', '하면', '뭐', '통', '하나'],
#  ['말로', '해서', '안', '되니', '계란', '던지지', '않을까'],
#  ['이래서', '한국인', '들', '이', '게임', '을', '잘', '하구나', 'ㅓ', 'ㅋㅋㅋㅋ'],
#  ['아무리',
#   '정치인',
#   '이',
#   '싫어도',
#   '칼',
#   '로',
#   '얼굴',
#   '긁는',
#   '건',
#   '아니다',
#   '명백한',
#   '살인',
#   '미수다'],
#  ['장난감', '총보', '다', '강한', '게', '짱', '돌'],
#  ['아', '한민족', '이', '에', '임', '만큼은', '세계', '원', '탑', '이', '지', 'ㅋㅋ'],
#  ['근데', '커터칼', '은', '존', '나', '심했다', '계란', '이면', '모를까', '칼', '을', '얼굴', '에다'],
#  ['전',
#   '에',
#   '아이돌',
#   '팬',
#   '이',
#   '항의',
#   '하는',
#   '표시',
#   '로',
#   '바닥',
#   '에',
#   '계란',
#   '던지던',
#   '거',
#   '생각난다'],
#  ['계란', '이', '너무', '아깝다', '요즘', '은', '계란', '비싼', '뎅'],
#  ['옆', '사랑', '이랑', '겹', '쳐', '보이는', '거'],
#  ['공무원',
#   '들',
#   '뭐',
#   '하냐',
#   'ㄹㅇ',
#   '니',
#   '들',
#   '우리',
#   '가',
#   '세금',
#   '내는',
#   '거',
#   '알',
#   '고',
#   '있냐'],
#  ['우리', '라면', '자살', '로', '위장', '할', '거', '같음', 'ㅋㅋ'],
#  ['폭력',
#   '이',
#   '아닌',
#   '말로',
#   '해결',
#   '하',
#   '라이',
#   '자막',
#   '넣으면서도',
#   '찝찝하지',
#   '않으',
#   '신지',
#   '요',
#   '국민',
#   '은',
#   '100',
#   '번',
#   '이고',
#   '1000',
#   '번',
#   '이고',
#   '말',
#   '합니다',
#   '국민',
#   '들',
#   '소리',
#   '를',
#   '귓',
#   '등',
#   '으로',
#   '듣고',
#   '무시',
#   '하는',
#   '게',
#   '누군데',
#   '요',
#   'ㅋ'],
#  ['정치', '에는', '기업', '도', '참여', '하고', '있어서', '국민', '의', '말로', '쉽게', '안', '됨'],
#  ['왜냐면', '던지면', '누군지', '모르니까'],
#  ['말', '이', '안', '되니', '폭력', '으로', '이', '어가', '는', '거지', 'ㅋㅋㅋ'],
#  ['진짜',
#   '성공한',
#   '사람',
#   '들',
#   '정치계',
#   '로',
#   '안',
#   '갔으면',
#   '좋겠음',
#   '잘',
#   '하든',
#   '말',
#   '든',
#   '모순',
#   '때문',
#   '에',
#   '망가지는',
#   '게',
#   '안쓰러',
#   '움'],
#  ['이', '것', '도', '모순', '임'],
#  ['외국', '사정', '은', '잘', '모르겠고', '솔직히', '우리나라', '몇몇', '은', '맞을', '만', '하다'],
#  ['마지막',
#   '영상',
#   '에',
#   '폭력',
#   '이',
#   '아닌',
#   '말로',
#   '라고',
#   '써',
#   '있는데',
#   '말로',
#   '해도',
#   '안',
#   '바뀌니깐',
#   '폭력',
#   '을',
#   '사용',
#   '하는',
#   '거지'],
#  ['썰전',
#   '에서는',
#   '고소',
#   '고발',
#   '하지',
#   '않겠다고',
#   '약속',
#   '해',
#   '놓고는',
#   '바로',
#   '어',
#   '겨',
#   '버리네'],
#  ['팩트', '광복절', '집회', '에서', '경찰', '폭행', '하다', '잡혀', '들어갔다'],
#  ['말로', '안', '되니까', '저러는', '거', '아닐까'],
#  ['그럼', '말', '잘', '하면', '되지'],
#  ['프로야구', '투수', '들', '보다', '제구', '가', '좋네', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '나도', '그럼', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['말로', '안', '되니까', '폭력', '을', '쓰는', '거지'],
#  ['어린이', '때', '하', '샘', '촉법', '땜', '에', '안', '덜', '림'],
#  ['근데',
#   '어째',
#   '우리나라',
#   '계란',
#   '던지는',
#   '인간',
#   '들',
#   '은',
#   '에',
#   '임',
#   '이',
#   '개',
#   '좋네',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['그', '말', '이', '맞다'],
#  ['헤드', '록', '이', '아니라', '어깨동무', '했는데', '뿌리친', '거', '잖아', 'ㅋㅋ'],
#  ['저', '때', '확실하게', '끝장', '냈어야'],
#  ['이낙연', '개란', '맞은', '거', '는', '안', '올리네'],
#  ['조금',
#   '생각',
#   '하면',
#   '무례하다는',
#   '생각',
#   '도',
#   '들고',
#   '통쾌하다는',
#   '생각',
#   '도',
#   '들고',
#   '오묘',
#   '하다'],
#  ['우리', '한국', '은', '저런', '거', '언제', '해볼까'],
#  ['계란', '투척', '연막탄', '투척'],
#  ['웃긴', '건', '진짜', '맞아야', '하는', '정치인', '도', '있다는', '것', '이다'],
#  ['몇', '개는', '잘', '했는데'],
#  ['대한민국', '농업', '제', '가', '반드시', '살려내겠습니다'],
#  ['진짜', '프로야구', '투수', '가', '던진', '게', '확실함'],
#  ['정치인', '도', '정말', '하기', '힘든', '직업', '이', '네', 'ㅋㅋ'],
#  ['인정', '활', '이든', '총', '이든', '투석', '이든'],
#  ['입술', '찢어졌겠는데', '아프겟다'],
#  ['김정은', '이나', '푸틴', '은', '계란', '맞을', '걱정', '은', '없겠네', 'ㅋㅋㅋㅋ'],
#  ['내', '도플갱어', '인가'],
#  ['맞소'],
#  ['도데', '체', '어', '케', '던져야', '계란', '이', '입', '에', '딱', '맞냐', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㄹㅇㅋㅋ'],
#  ['바로',
#   '고소',
#   '당',
#   '하고',
#   '국정',
#   '윈',
#   '지하실',
#   '로',
#   '끌려가서',
#   '온갖',
#   '고문',
#   '은',
#   '다',
#   '당할',
#   '듯'],
#  ['누구',
#   '그것',
#   '을',
#   '찢는다는',
#   '사람',
#   '보단',
#   '윤석',
#   '열',
#   '총장',
#   '이',
#   '대통령',
#   '되는',
#   '게',
#   '더',
#   '현명한',
#   '듯'],
#  ['이',
#   '분',
#   '잘',
#   '모르지만',
#   '도리',
#   '도리',
#   '를',
#   '너무',
#   '하셔서',
#   '너무',
#   '정신',
#   '이',
#   '없네요',
#   '저만',
#   '그런',
#   '가요'],
#  ['대선',
#   '출마',
#   '를',
#   '바라신다면',
#   '인터뷰',
#   '할',
#   '때',
#   '목',
#   '돌아가는',
#   '습관',
#   '부터',
#   '고치셔야',
#   '겠습니다',
#   '보는',
#   '사람',
#   '도',
#   '따라',
#   '배우',
#   '겠네요'],
#  ['03250325', '미어', '캣', '인', '줄', 'ㅋㅋㅋㅌ'],
#  ['그',
#   '예외',
#   '들',
#   '이',
#   '언론',
#   '에',
#   '나오지',
#   '않게',
#   '잘',
#   '처신',
#   '했다',
#   '봅니다',
#   '그리고',
#   '한',
#   '가지',
#   '처가',
#   '힘',
#   '이',
#   '없었다면',
#   '장모',
#   '가',
#   '없었다면',
#   '총장',
#   '했을까',
#   '죄',
#   '를',
#   '지었으면',
#   '벌',
#   '을',
#   '받아야지',
#   '범죄',
#   '에',
#   '나이',
#   '가',
#   '있나'],
#  ['도리', '도리', '밖에', '안', '보이', '네'],
#  ['공정하게',
#   '붙으면',
#   '자격',
#   '미달',
#   '아니냐',
#   '중소기업',
#   '면접',
#   '가',
#   '서도',
#   '저러면',
#   '바로',
#   '탈락',
#   '이다'],
#  ['고개',
#   '를',
#   '정신없이',
#   '흔들면서',
#   '도리',
#   '도리',
#   '하는',
#   '이유',
#   '는',
#   '내적',
#   '으로',
#   '확신',
#   '이',
#   '없고',
#   '굉장히',
#   '불안하기',
#   '때문'],
#  ['솔직히', '대통령', '감은', '아니지'],
#  ['한마디',
#   '한마디',
#   '할',
#   '때',
#   '마다',
#   '가만',
#   '있지',
#   '못',
#   '하시고',
#   '진정',
#   '성',
#   '보다는',
#   '건들',
#   '건들',
#   '도리',
#   '도리',
#   '잘',
#   '보았습니다'],
#  ['도리', '도리', '눈', '아프다'],
#  ['고개', '좀', '고만', '흔들어라', '왜', '이리', '산만', '하냐'],
#  ['도대체',
#   '뭔',
#   '데',
#   '갑자기',
#   '튀어나와서',
#   '대선',
#   '까지',
#   '뭔',
#   '땀',
#   '시',
#   '이렇게',
#   '인기',
#   '가',
#   '많은',
#   '겨진',
#   '심',
#   '으로',
#   '궁금'],
#  ['검찰',
#   '시절',
#   '중립',
#   '을',
#   '지켰는가',
#   '언행',
#   '불',
#   '일치',
#   '이런',
#   '사람',
#   '이',
#   '대통령',
#   '이',
#   '되겠다고',
#   '나오고',
#   '떨어지는',
#   '콩',
#   '고물',
#   '주워',
#   '먹을려고',
#   '모인',
#   '인간',
#   '들',
#   '이나',
#   '띄워주는',
#   '언론',
#   '이나',
#   '도',
#   '찐',
#   '개',
#   '찐에',
#   '라잇',
#   '깜',
#   '도',
#   '안',
#   '되는',
#   '인간',
#   '아',
#   '공부',
#   '더하고',
#   '와라'],
#  ['집중', '을', '못', '하는', '거지', '도리', '도리', '중국', '김치', '먹지', '맙시', '다'],
#  ['저',
#   '사람',
#   '말',
#   '할',
#   '때',
#   '목',
#   '을',
#   '좌우',
#   '로',
#   '계속',
#   '왔다',
#   '갔다',
#   '하는',
#   '행위',
#   '는',
#   '행동',
#   '심리학',
#   '에서',
#   '현실',
#   '부정',
#   '할',
#   '때',
#   '즉',
#   '거짓말',
#   '할',
#   '때',
#   '하는',
#   '행동',
#   '임'],
#  ['진짜', '정치', '경험', '없이', '대통령', '바로', '되면', '레전드', '네'],
#  ['제', '2', '의', '박', '그네', '인', '줄'],
#  ['그래도',
#   '아직',
#   '석',
#   '열',
#   '이',
#   '형님',
#   '은',
#   '아니지',
#   '정치',
#   '경력',
#   '1년',
#   '도',
#   '없는',
#   '사람',
#   '이',
#   '공부',
#   '만',
#   '한다',
#   '해서',
#   '국정',
#   '수행',
#   '을',
#   '해야',
#   '하는',
#   '대통령',
#   '될',
#   '수',
#   '있나',
#   '그리고',
#   '25',
#   '세',
#   '박성민',
#   '비서',
#   '관',
#   '사회',
#   '경험',
#   '없다고',
#   '왜',
#   '뽑았냐고',
#   '뭐라',
#   '하면서',
#   '윤석열',
#   '형님',
#   '도',
#   '정치',
#   '경력',
#   '이',
#   '1',
#   '도',
#   '없는데',
#   '뽑아',
#   '준다는',
#   '게',
#   '어',
#   '불성',
#   '설',
#   '일',
#   '관성',
#   '있게',
#   '해야지',
#   '박통',
#   '령',
#   '역대',
#   '급',
#   '삽질',
#   '로',
#   '반',
#   '사',
#   '이익',
#   '보고',
#   '반짝',
#   '스타',
#   '로',
#   '정권',
#   '잡은',
#   '문',
#   '통령',
#   '지난',
#   '4년',
#   '간',
#   '어떻게',
#   '말',
#   '아',
#   '드시는',
#   '지',
#   '잘',
#   '봤지',
#   '않나',
#   '이번',
#   '에도',
#   '반짝',
#   '스타',
#   '로',
#   '거기',
#   '다',
#   '정치',
#   '경험',
#   '1',
#   '도',
#   '없는',
#   '사람',
#   '되면',
#   '어떻게',
#   '될런',
#   '지',
#   '될',
#   '거',
#   '면',
#   '차라리',
#   '홍카',
#   '콜라',
#   '가',
#   '되야',
#   '된다고',
#   '봄',
#   '기자',
#   '들',
#   '도',
#   '좀',
#   '경제',
#   '질문',
#   '같은',
#   '거나',
#   '좀',
#   '물어보지'],
#  ['머리', '를', '가만히', '놔두질', '못', '하는', '듯'],
#  ['도리도', '리까', '꿍', 'ㅋㅋ'],
#  ['여기', '서', '문제', '윤석열', '은', '도리', '도리', '를', '총', '몇', '번', '했을까요'],
#  ['대통령', '하실', '분', '은', '아닌', '거', '같네요'],
#  ['도리도', '리뱅뱅'],
#  ['카메라',
#   '기자',
#   '들',
#   '과',
#   '눈',
#   '마주치며',
#   '얘기',
#   '하느라',
#   '도리',
#   '도리',
#   '된',
#   '것',
#   '같은',
#   '디',
#   'ㅋ'],
#  ['우리',
#   '가',
#   '기',
#   '자',
#   '회견',
#   '에서',
#   '한두',
#   '번',
#   '봅니까',
#   '저',
#   '거',
#   '행동',
#   '심리학',
#   '에서',
#   '현실',
#   '부정',
#   '할',
#   '때',
#   '나오는',
#   '행동',
#   '입니다',
#   '지금',
#   '거짓말',
#   '중',
#   '이란',
#   '얘기',
#   '죠'],
#  ['술',
#   '먹고',
#   '봐서',
#   '그런',
#   '가',
#   '뭔',
#   '소린',
#   '지',
#   '못',
#   '알',
#   '아',
#   '들',
#   '음',
#   '아',
#   '술',
#   '끊어',
#   '여야',
#   '지'],
#  ['안뇽'],
#  ['지지율', '이', '높잖아', '이재명', '이랑', '다투고', '있지', '않냐'],
#  ['어떻게',
#   '이렇게',
#   '말',
#   '할',
#   '수',
#   '있을지',
#   'ㅠㅜ',
#   '하늘',
#   '이',
#   '내려',
#   '않은',
#   '꼴',
#   '이',
#   '되겠네요',
#   '국민',
#   '들',
#   '정신',
#   '바짝',
#   '차려야지요'],
#  ['진지하지', '못', '하기', '땜', '이지', '요'],
#  ['어짜피', '들러리', '인데', '출마', '함', '으로', '얻는', '게', '뭐', '지'],
#  ['무슨',
#   '검사',
#   '가',
#   '대선',
#   '을',
#   '출마',
#   '를',
#   '하냐',
#   '다른',
#   '나라',
#   '에서는',
#   '이렇게',
#   '잘',
#   '안',
#   '하는데',
#   '무척',
#   '우리나라',
#   '에서만',
#   '그러냐',
#   '검사',
#   '는',
#   '검사',
#   '일',
#   '을',
#   '하지',
#   '왜',
#   '정치',
#   '를',
#   '대해',
#   '서',
#   '관여',
#   '하냐'],
#  ['지지', '합니다', '꼭', '대통령', '이', '되', '주시길', '바랍니다'],
#  ['왜',
#   '이렇게',
#   '도리',
#   '도리',
#   '하지',
#   '홍준표',
#   '와',
#   '선의',
#   '의',
#   '대결',
#   '기',
#   '대합',
#   '니',
#   '다'],
#  ['정직하지',
#   '못',
#   '한',
#   '사람',
#   '이',
#   '하는',
#   '행동',
#   '나',
#   '자신',
#   '도',
#   '설득',
#   '못',
#   '시켜서',
#   '하는',
#   '행동',
#   '도리',
#   '도리'],
#  ['ㅋㅋㅋㅋ', '빵', '터짐'],
#  ['도리', '도리', '정신', '없네'],
#  ['마이크', '알뜰하게', '잘', '쓰시', '는', '편'],
#  ['석', '열', '아', '니', '기준', '의', '도덕성', '은', '도대체', '뭐', '니'],
#  ['저런',
#   '사람',
#   '이',
#   '화가',
#   '나네요',
#   '모든',
#   '걸',
#   '떠나서도',
#   '의',
#   '리가',
#   '있어야',
#   '합니다',
#   '정말',
#   '저',
#   '사람',
#   '은',
#   '아닌',
#   '듯',
#   'ㅜㅜ'],
#  ['대통령', '이란', '자리는', '반짝', '인기', '로', '될', '수', '있는', '자리', '가', '아니다'],
#  ['윤석열',
#   '전',
#   '총장',
#   '님',
#   '말씀',
#   '에',
#   '감동',
#   '받았습니다',
#   '자유',
#   '국가',
#   '는',
#   '아름답게',
#   '성장합니다',
#   '듣던',
#   '중',
#   '속이',
#   '시원합니다'],
#  ['이재명',
#   '홍준표',
#   '기대합니다',
#   '평생',
#   '네거티브',
#   '따윈',
#   '하지',
#   '않고',
#   '공약',
#   '과',
#   '비전으로만',
#   '승부',
#   '하신',
#   '2분',
#   '이런',
#   '분',
#   '이',
#   '대선',
#   '토론',
#   '이라는',
#   '검증',
#   '장소',
#   '에',
#   '나서야',
#   '합니다'],
#  ['홍준표', '도', '이번', '에', '나오나요'],
#  ['우리',
#   '국민',
#   '들',
#   '은',
#   '정확한',
#   '정무',
#   '적',
#   '감각',
#   '과',
#   '비전',
#   '구체',
#   '적',
#   '인',
#   '독자',
#   '적',
#   '경제정책',
#   '정치',
#   '적',
#   '능력',
#   '이',
#   '있는',
#   '홍준표',
#   '이재명',
#   '같은',
#   '사람',
#   '을',
#   '대권',
#   '후보',
#   '로',
#   '원합니다',
#   '윤석열',
#   '총장',
#   '은',
#   '검사',
#   '로',
#   '썬',
#   '그',
#   '의',
#   '논란',
#   '을',
#   '제외',
#   '하고',
#   '꽤',
#   '좋은',
#   '사람',
#   '인',
#   '건',
#   '많은',
#   '국민',
#   '들',
#   '께서',
#   '동의',
#   '하시는',
#   '건',
#   '사실',
#   '이지만',
#   '이',
#   '둘',
#   '의',
#   '20년',
#   '간',
#   '쌓아',
#   '온',
#   '비전을',
#   '단',
#   '4',
#   '개월',
#   '만에',
#   '절대',
#   '홍준표',
#   '이재명',
#   '같은',
#   '정무',
#   '적',
#   '감각',
#   '과',
#   '경험',
#   '비전을',
#   '쌓을',
#   '수',
#   '없습니다',
#   '우리',
#   '이성',
#   '을',
#   '보고',
#   '판단',
#   '합시다'],
#  ['에이', '이건', '아니죠', '직업', '에', '귀', '천이', '어딨어요'],
#  ['애초', '에', '민주당', '이', '진보', '정당', '인지', '모르겠다'],
#  ['저런', '사람', '은', '진짜', '목숨', '2', '개인', '가보네'],
#  ['진짜', '위험', '스'],
#  ['보는', '것', '만으로도', '긴장', '팍', '되네', 'ㄷㄷ'],
#  ['아무',
#   '이탈',
#   '없이',
#   '무사히',
#   '백',
#   '사장',
#   '에',
#   '착륙',
#   '한',
#   '게',
#   '더',
#   '신기하',
#   '넼',
#   'ㅋㅋㅌㅌㅋㅋㅋㅋㅌㅌ'],
#  ['남자', '가', '빨리', '죽는', '이유'],
#  ['나중',
#   '엔',
#   '하늘',
#   '에서',
#   '식사',
#   '중',
#   '에',
#   '손님',
#   '이',
#   '날아와서',
#   '합석',
#   '하',
#   '는',
#   '거',
#   '아니냐',
#   'ㅋㅋㅋㅋ'],
#  ['출근', '할', '때', '좋겟네'],
#  ['난', '저', '거', '1', '경', '을', '준다고', '해도', '못', '해'],
#  ['잠꼬대', '로', '떨어지는', '순간'],
#  ['하산'],
#  ['이', '거', '자다가', '360', '도', '돌는', '사람', '은', '바로', '떨어질', '것', '같아요'],
#  ['왠지',
#   '저',
#   '아저씨',
#   '자는',
#   '척',
#   '하고',
#   '안',
#   '잘',
#   '듯',
#   '저기',
#   '서',
#   '어떻게',
#   '잠',
#   'ㅋㅋㅋㅋㅋ',
#   '죽',
#   '을',
#   '수도',
#   '있는데',
#   'ㅋㅋㅋㅋ'],
#  ['바베큐', '장비', '를', '들고', '올라가는', '게', '웃기', '네'],
#  ['야', '침대'],
#  ['보고',
#   '만',
#   '있어도',
#   'ㅎ',
#   '후',
#   '훗',
#   '이',
#   '이',
#   '정도',
#   '야',
#   '뭐',
#   '아어랏',
#   '여기',
#   '에',
#   '누가',
#   '오렌지',
#   '주스',
#   '흘렸엄'],
#  ['야', '괜찮아', 'ㅋㅋ', '그냥', '하늘', '일', '뿐이잖아', '안', '디져', 'ㅋㅋ'],
#  ['영화', '실사판', '인', '가', 'ㅋㅋ', '이제', '풍선', '이랑', '집', '만', '있음', '되겠네요'],
#  ['와', '저걸', '창륙', '하리', 'ㅣ'],
#  ['꿈', '은', '위대하다'],
#  ['빌딩', '숲', '에서', '높은', '빌딩', '에', '꿍', '하면', '상상', '만', '해도', 'ㄷㄷ', '하네'],
#  ['보는', '내', '가', '더', '쫄리', '네'],
#  ['엄청난',
#   '스릴',
#   '이',
#   '느',
#   '지지',
#   '만',
#   '그만큼',
#   '죽',
#   '을',
#   '수도',
#   '있다',
#   '극',
#   '과',
#   '극',
#   '이',
#   '다'],
#  ['아', '난', '쫄려', '서', '못', '하겠다'],
#  ['난',
#   '누가',
#   '조종',
#   '해주는',
#   '거',
#   '타는',
#   '줄',
#   '알았는데',
#   '심지어',
#   '본인',
#   '이',
#   '조종',
#   '하는',
#   '거',
#   '라고',
#   '말',
#   '도',
#   '안',
#   '돼',
#   '난',
#   '아마',
#   '못',
#   '버텨서',
#   '기절',
#   '했을',
#   '듯'],
#  ['80420420초', '에', '나오는', '노래', '제목', '뭔가', '요'],
#  ['80303303', '무한'],
#  ['80045045',
#   '와',
#   '저기',
#   '다',
#   '관짝밈',
#   '노래',
#   '를',
#   '트',
#   '네',
#   '사망',
#   '플래그',
#   '도',
#   '아니곸',
#   'ㅋㅋㅋㅋㅋㅋ'],
#  ['애초', '에', '잠', '이', '든다는', '게', '대단해요', 'ㄷㄷ'],
#  ['와중', '에', '이', '모범', '택시', '에서', '나온', '거', '잖아', 'ㅋㅋㅋㅋ'],
#  ['한번', '해보고', '싶은데', '하고', '싶지는', '않음'],
#  ['저', '거', '자칫', '잘못', '하면', '목숨', '을', '잃으면', '어떻', '해', '요'],
#  ['멋지', '다', 'ㄷㄷ'],
#  ['옷', '까지', '잠옷', '이었으면', '삼', '위', '일체'],
#  ['엄마',
#   '아들',
#   '일어나',
#   '아들',
#   '엄마',
#   '엄마',
#   'ㅋㅋㅋ',
#   '그러게',
#   '엄마',
#   '가',
#   '빨리',
#   '일어나라고',
#   '했짘',
#   'ㅋㅋㅋㅋ'],
#  ['침대', '날다'],
#  ['고기', '맜잇어', '보인다'],
#  ['와대', '박', '저걸'],
#  ['고', '인물', '이', '다', '한두', '번', '한', '게', '아니네', '보', '니까', 'ㅋㅋ'],
#  ['인형', '고양', '인', '주', '알았네'],
#  ['아들',
#   '엄마',
#   '어딨어',
#   '엄마',
#   '너',
#   '하늘',
#   '에',
#   '날',
#   '고',
#   '있어',
#   '아들',
#   '엄마',
#   '이',
#   '불',
#   '떨어졌는데',
#   '어케',
#   '해',
#   '엄마',
#   '떨어',
#   '트리',
#   '면',
#   '너',
#   '는',
#   '내',
#   '아들',
#   '아니야',
#   '아들',
#   '누구세요'],
#  ['자다가', '이', '불', '차면', '영원히', '저', '이불', '이랑', '안녕', '인', '건가'],
#  ['이', '실제', '로', '가능했을', '줄', '이야'],
#  ['떨어지는', '꿈', '꾸면', '진짜', '무섭겠다'],
#  ['ㅇ', '오토바이', '가', '하늘', '을', '날아요'],
#  ['잠버릇', '나쁘면', 'ㅎㄷㄷ'],
#  ['이', '거', '마지막', '에', '나온', '노래', '제목', '이', '뭐', '였죠'],
#  ['와', '심지어', '착륙', '도', '스무', '스'],
#  ['와', '진짜', '없는', '고소공포증', '도', '생기겠다'],
#  ['저', '분', '이니까', '가능한', '거'],
#  ['재밌겠다'],
#  ['와', '완전', '멋있다'],
#  ['영화', '같다', '대', '박', '인데'],
#  ['왜', '보는', '동안', '땀', '이', 'ㅋㅋ'],
#  ['20년',
#   '전',
#   '미래',
#   '에는',
#   '자동차',
#   '가',
#   '하늘',
#   '을',
#   '날겠지',
#   '현재',
#   '하늘',
#   '을',
#   '나',
#   '는',
#   '침대'],
#  ['캬', '대단하다', '진짜'],
#  ['진짜', '영화', '보는', '거', '같네', 'ㅋㅋㅋㅋ', '저러다가', '집', '까지', '띄우겠네'],
#  ['ㅋㅋㅋㅋ'],
#  ['개인', '의', '취향', '이라', '뭐라', '하긴', '그렇지만'],
#  ['와', '기네스북', '저', '리가', '라네'],
#  ['저', '게', '진짜', '남자', '지', '부럽다'],
#  ['와'],
#  ['저', '게', '그', '에어', '매트', '라는', '것', '인가'],
#  ['신', '박', '한', '가구', '이사', '방법'],
#  ['자고',
#   '일어났는데',
#   '하늘',
#   '인',
#   '거',
#   '까먹고',
#   '집',
#   '인',
#   '줄',
#   '알',
#   '고',
#   '뒤척',
#   '이',
#   '다가',
#   '떨어지면'],
#  ['헬리콥터', '같은', '거', '이', '메', '달렸나', '했더니', '아니었어'],
#  ['꿈', '속', '에서', '가능한', '걸', '실제', '로', '하는', '그', '는', '대체'],
#  ['와'],
#  ['어릴', '때', '꿈이였던', '하늘', '을', '나', '는', '침대', '라'],
#  ['아', '무서워도', '한', '번은', '타', '보고', '싶다'],
#  ...]

# %%
'''
data['token'] = train_token
data
data.to_csv('mbig_띄어쓰기_토큰.csv',encoding='utf-8-sig')
'''

# %%
corpus = Corpus()
corpus.fit(train_token,window=30)

# %%
#model
glove = Glove(no_components=128, learning_rate=0.005)
# %time glove.fit(corpus.matrix, epochs=50,no_threads=4,verbose=False)
glove.add_dictionary(corpus.dictionary)

#save
#glove.save('glove_w20_epoch50.model') #14.4s
#glove.save('glove_w20_epoch100.model') #28.3s
# Out:
# Wall time: 32.1 s

# %%
glove.save('glove_w30_epoch50.model')
#load glove model
glove_model = Glove.load('glove_w30_epoch50.model')

# %%
# word dict 생성
word_dict = {}
for word in  glove_model.dictionary.keys():
    word_dict[word] = glove_model.word_vectors[glove_model.dictionary[word]]
print('[Success !] Lengh of word dict... : ', len(word_dict))

# save word_dict
with open('glove_word_dict_128.pickle', 'wb') as f:
    pickle.dump(word_dict, f)
print('[Success !] Save word dict!...')
# Out:
# [Success !] Lengh of word dict... :  13185
# [Success !] Save word dict!...

# %%
word_dict
# Out:
# {'이': array([-0.26529128,  0.26147053,  0.27184486, -0.2652895 , -0.265439  ,
#         -0.30075339,  0.19639745,  0.22448401, -0.17370858, -0.16872191,
#         -0.28355053,  0.24828717,  0.16044942,  0.18596379,  0.14013999,
#         -0.30335627, -0.22695199,  0.2973106 ,  0.29220754,  0.30351746,
#         -0.31007211, -0.0435667 , -0.29205592,  0.1754889 , -0.13756372,
#         -0.28134583,  0.30780118,  0.16092886,  0.28078928, -0.27241159,
#          0.24138329,  0.10947663,  0.28599794, -0.28686481, -0.09945837,
#         -0.13288404, -0.09795857, -0.18827219,  0.29710126,  0.21631473,
#          0.2396801 ,  0.22378396, -0.25670488,  0.02601648, -0.30156248,
#         -0.02534616,  0.20606973, -0.20274073, -0.23220773,  0.3078958 ,
#          0.16426803,  0.21465396,  0.29544591, -0.26043745,  0.2490718 ,
#          0.02144419, -0.3009968 , -0.32752763, -0.15086503, -0.19057342,
#          0.29612792,  0.27013644, -0.28425484,  0.2644629 , -0.04732943,
#          0.26353838,  0.2001232 , -0.30592189,  0.15135546,  0.25360515,
#          0.23659592, -0.31353915,  0.16470487,  0.27668938, -0.28331123,
#          0.31745017,  0.32404395, -0.25997183,  0.07847739, -0.19333384,
#          0.20872153, -0.25739496,  0.23498777, -0.20122722,  0.23444058,
#          0.21685198,  0.2249019 , -0.21285354, -0.2941965 ,  0.1842702 ,
#         -0.08341352, -0.23644554, -0.30402405, -0.03865701,  0.13007509,
#          0.32189254, -0.10301059, -0.17299529, -0.24358124, -0.15066032,
#         -0.26310063, -0.18022913, -0.28453961,  0.28480095,  0.28263541,
#         -0.24664318, -0.24400212,  0.26590142, -0.16374547,  0.1993821 ,
#         -0.25139701, -0.1148704 , -0.17842232, -0.31233521, -0.26148521,
#         -0.20758551, -0.20302712, -0.00769922,  0.14614202,  0.08003772,
#          0.20986534,  0.2407657 ,  0.14224314, -0.15148002, -0.20214299,
#          0.11656813, -0.29514429,  0.24906943]),
#  '거': array([-0.17016897,  0.16287808,  0.16585515, -0.16265194, -0.16347944,
#         -0.18934679,  0.11576345,  0.1338356 , -0.10517382, -0.09913669,
#         -0.18549373,  0.15698099,  0.09059384,  0.11247714,  0.07667337,
#         -0.18391774, -0.13674645,  0.18977687,  0.18379047,  0.18822876,
#         -0.19089082, -0.02320028, -0.17880276,  0.10074645, -0.07967281,
#         -0.16641089,  0.18586896,  0.09102706,  0.17599605, -0.16525981,
#          0.14632916,  0.06428919,  0.17707964, -0.17879931, -0.04851518,
#         -0.077478  , -0.06261574, -0.1028132 ,  0.18609009,  0.12861225,
#          0.14967847,  0.14092273, -0.15893063,  0.01339324, -0.18914247,
#         -0.01055662,  0.12218955, -0.11649724, -0.14395093,  0.19510302,
#          0.09105795,  0.13334127,  0.18625307, -0.1587594 ,  0.15512202,
#          0.01235682, -0.18967752, -0.20324159, -0.08616872, -0.115233  ,
#          0.18759208,  0.16589733, -0.18524608,  0.15739487, -0.02398156,
#          0.15921745,  0.11933979, -0.18304043,  0.09021106,  0.15460653,
#          0.14319387, -0.19514399,  0.09288748,  0.1678715 , -0.1784207 ,
#          0.20523619,  0.20741423, -0.15986604,  0.04291593, -0.11158931,
#          0.12578009, -0.15263041,  0.13866328, -0.11848369,  0.1375801 ,
#          0.12576514,  0.13941913, -0.12911969, -0.18847595,  0.1125935 ,
#         -0.04052483, -0.14007054, -0.19069993, -0.01784047,  0.07134869,
#          0.20870671, -0.05373255, -0.09250014, -0.14904427, -0.08282158,
#         -0.16745861, -0.10793288, -0.17586418,  0.16574936,  0.1807502 ,
#         -0.14995615, -0.14190712,  0.15887597, -0.08778825,  0.11615422,
#         -0.15840765, -0.06592066, -0.10315984, -0.19364962, -0.15170526,
#         -0.12046504, -0.121563  , -0.00980417,  0.09061322,  0.04378243,
#          0.130704  ,  0.1549935 ,  0.07864214, -0.08839471, -0.11594646,
#          0.05921557, -0.1864407 ,  0.15034158]),
#  '그거': array([-6.30376899e-04,  2.78038107e-03,  8.56883097e-04, -3.85087282e-03,
#         -1.46587576e-03, -3.28027108e-04, -2.07635352e-03,  3.96004790e-03,
#         -5.44806124e-04,  1.81358771e-03,  1.62556132e-03,  3.31062905e-03,
#          2.03317705e-03,  5.75186727e-04, -9.79212098e-04, -3.19743306e-03,
#          4.18603619e-04, -2.73656697e-03,  1.36787106e-03,  3.08459064e-04,
#         -1.75952000e-04,  1.56137869e-04, -1.43014766e-03, -1.48135202e-03,
#         -4.78507732e-04,  5.02771825e-04, -1.37463905e-03,  1.99703053e-03,
#         -2.22533662e-03, -2.35681677e-03, -1.25295386e-03,  3.22957973e-03,
#         -1.94264071e-03,  2.49957289e-03,  7.96789425e-04,  2.33260347e-03,
#          1.45462232e-03,  2.00749660e-03,  2.32433204e-03, -3.36462458e-03,
#         -1.79144393e-03, -2.55980516e-03, -4.05952358e-03, -7.89934985e-04,
#          3.27510285e-04, -1.17802700e-03,  3.16794857e-03,  8.86293682e-04,
#         -4.28439764e-03,  9.89712983e-04, -2.55447304e-03,  3.81911040e-03,
#          2.25702086e-03, -3.66628515e-03, -8.15640100e-04, -1.62857718e-03,
#          1.07835258e-03, -3.20797603e-03,  1.85904484e-03, -3.05889763e-04,
#          5.74475074e-03, -7.49562249e-04,  8.83917465e-05, -4.79451792e-03,
#          2.44020455e-03,  5.09665142e-03,  4.16400339e-03, -5.20672533e-03,
#         -5.81983210e-03,  3.45625881e-03, -4.05108022e-03, -5.85536565e-03,
#         -7.49736430e-03, -4.20809241e-03, -1.49651601e-03,  6.99569246e-03,
#          1.93146205e-03,  1.42943807e-03, -4.31013762e-03,  7.07146290e-04,
#         -7.58616383e-03, -1.10562477e-03, -5.50571133e-03,  4.02417555e-03,
#          1.72762832e-03, -5.14807821e-03, -6.43925360e-03,  1.24525308e-03,
#          5.09961396e-04,  5.18961816e-03, -4.41659349e-04,  9.03962866e-04,
#         -5.76716902e-03, -1.36392139e-03, -3.99010502e-03, -1.88037289e-03,
#         -4.00435265e-03,  7.98422677e-04,  4.41228679e-03,  3.63917860e-03,
#          6.89660102e-03,  7.42008572e-04, -1.25616374e-03, -2.72468373e-04,
#         -1.22951379e-03, -1.13911294e-03, -6.35660226e-03,  2.36525674e-03]),
#  '그': array([-0.11004164,  0.10307557,  0.10350026, -0.10108223, -0.1003266 ,
#         -0.12453642,  0.07239021,  0.08616546, -0.06389777, -0.06039643,
#         -0.11534255,  0.10111597,  0.05909319,  0.07084962,  0.0519015 ,
#         -0.12049036, -0.08241497,  0.12188349,  0.11847808,  0.1237671 ,
#         -0.12397032, -0.02054006, -0.11601316,  0.06027182, -0.04725623,
#         -0.1136915 ,  0.11611506,  0.0611824 ,  0.11532376, -0.10694149,
#          0.09129328,  0.0375763 ,  0.11486565, -0.11137911, -0.03223338,
#         -0.05506242, -0.03119905, -0.07440342,  0.11619631,  0.08228279,
#          0.09709936,  0.08789226, -0.10556226,  0.01089798, -0.11724884,
#         -0.01454826,  0.08132133, -0.07793687, -0.09125626,  0.12105156,
#          0.06656866,  0.08621856,  0.12080776, -0.10533286,  0.09478203,
#          0.00863057, -0.11506524, -0.13511617, -0.05698133, -0.06821583,
#          0.12355169,  0.10696966, -0.1208713 ,  0.10329349, -0.0198719 ,
#          0.10070182,  0.07431809, -0.11791362,  0.06110242,  0.10313708,
#          0.08717405, -0.12348872,  0.06004598,  0.10671758, -0.10680414,
#          0.13237456,  0.13915252, -0.10012234,  0.03623025, -0.07414429,
#          0.07542936, -0.09598868,  0.0887332 , -0.07751679,  0.09166885,
#          0.08224117,  0.08496463, -0.08413461, -0.12216107,  0.06241022,
#         -0.0248396 , -0.08550052, -0.11980625, -0.0133656 ,  0.04418739,
#          0.13036889, -0.03815713, -0.06507007, -0.09263064, -0.05480231,
#         -0.09749079, -0.0679315 , -0.11154905,  0.10522064,  0.1118088 ,
#         -0.10048572, -0.0963535 ,  0.1026763 , -0.06040769,  0.07020143,
#         -0.09502554, -0.03991313, -0.06112744, -0.12553555, -0.10271601,
#         -0.07342536, -0.07428565,  0.00154849,  0.05215488,  0.03183199,
#          0.0811975 ,  0.09933723,  0.04876061, -0.06084709, -0.07318483,
#          0.04242369, -0.1159502 ,  0.09792385]),
#         -0.13952694,  0.14617631,  0.07714685,  0.13718777, -0.12870566,
#          0.11482307,  0.04431195,  0.14277474, -0.14260227, -0.03625063,
#         -0.06515535, -0.04121542, -0.08230984,  0.13760421,  0.0937827 ,
#          0.11560112,  0.10671452, -0.12691511,  0.01439897, -0.14370496,
#         -0.01575006,  0.10126305, -0.09284725, -0.10903567,  0.15758353,
#          0.07416681,  0.10694979,  0.14720057, -0.12986949,  0.11735668,
#          0.00851317, -0.14564191, -0.16537302, -0.06126689, -0.08941559,
#          0.14295067,  0.12822892, -0.14540492,  0.11827617, -0.02312976,
#          0.12397393,  0.08689652, -0.15136666,  0.07084231,  0.11885226,
#          0.11260539, -0.15762557,  0.08004284,  0.13773739, -0.13105865,
#          0.15804687,  0.16518394, -0.12644965,  0.0454723 , -0.08687592,
#          0.09769182, -0.11896067,  0.11007036, -0.09416902,  0.11700783,
#          0.10156234,  0.10818252, -0.10282827, -0.15347822,  0.07999268,
#         -0.03833748, -0.10881506, -0.15234574, -0.01009678,  0.05621922,
#          0.16352051, -0.04333071, -0.08421241, -0.11623693, -0.06014934,
#         -0.12441971, -0.07828583, -0.14212634,  0.13003595,  0.14161737,
#         -0.12300306, -0.1126774 ,  0.12664214, -0.07096371,  0.08530664,
#         -0.11755705, -0.04574864, -0.08144127, -0.15523025, -0.12376807,
#         -0.09172961, -0.09955522, -0.00229071,  0.07000696,  0.04081125,
#          0.09857216,  0.11741672,  0.05589896, -0.07476715, -0.08800154,
#          0.05587595, -0.15087182,  0.11698395]),
#  '질주': array([-3.19458107e-04,  1.22762017e-03, -3.74660422e-03,  4.52624265e-03,
#          6.76288923e-04,  4.21189207e-03, -5.23160961e-03,  6.47574116e-04,
#          4.48782395e-03,  3.28999495e-05,  1.01309466e-04,  1.89901549e-03,
#          1.68747007e-03, -1.50982776e-03, -3.16793258e-04, -7.68667192e-04,
#          7.07066788e-04, -4.82410685e-03, -5.13915277e-03, -5.30643392e-03,
#          5.80864365e-03,  6.68823758e-04,  5.24595343e-03, -1.22970060e-03,
#         -3.80945370e-04,  4.99459604e-03, -4.33120344e-03, -2.19853079e-03,
#         -8.17725223e-04,  3.57349762e-03, -2.13681886e-03,  8.78341144e-04,
#         -3.82251279e-03,  3.34472225e-03,  2.88784476e-03,  1.82678965e-03,
#         -2.40054053e-03,  4.72999799e-03, -3.37110168e-03, -3.51009522e-03,
#         -5.28719117e-03, -3.46527401e-03,  1.62054519e-03, -2.23585762e-03,
#          5.01117830e-03, -1.52106808e-03, -7.21571029e-04,  4.69062812e-03,
#          4.32879322e-03, -1.34337342e-03, -9.66957645e-04,  5.02579919e-04,
#         -3.69600117e-03,  4.00279675e-03,  2.76360199e-05, -4.68167144e-04,
#         -1.74449473e-04,  1.20106651e-04,  2.97728738e-03,  3.37576038e-03,
#         -6.21820995e-03, -1.92472093e-03,  3.98593741e-04, -2.56416645e-03,
#         -2.04128997e-03, -1.32040199e-03, -1.71147670e-03,  4.03607031e-03,
#          8.47127030e-04, -1.38012621e-03, -3.58324484e-03,  3.94877278e-03,
#         -2.12057213e-03, -1.87732738e-03,  1.15542150e-03, -8.82731529e-04,
#         -3.49277607e-03,  2.05153807e-03, -1.92796384e-03, -6.99477048e-04,
#          6.93637401e-04,  5.73656217e-03, -4.87414489e-03,  1.68026786e-03,
#         -5.02720941e-03,  9.54586591e-04, -7.59918198e-04,  2.75886327e-03,
#          6.24762251e-04, -2.58668191e-03,  3.41813586e-03,  5.03505768e-03,
#          5.65525406e-03, -4.37601244e-04,  2.17619966e-03, -5.34190009e-03,
#          9.18996992e-04,  3.10516095e-04,  1.81864819e-03, -2.19262832e-03,
#          5.84820070e-04, -1.69492693e-03, -1.50666019e-03,  3.23686342e-04,
#         -2.88350569e-03,  2.74646834e-03,  3.82675861e-03, -3.09536399e-03,
#         -1.65367903e-03, -4.62068369e-03,  3.20090122e-03, -1.49189467e-03,
#          3.86164242e-03,  6.25055619e-03,  3.45584078e-03,  4.40663656e-04,
#         -7.32924912e-04, -3.56714525e-03, -4.61315673e-03, -1.37980792e-03,
#         -1.25764276e-03, -4.83170862e-03, -3.11529408e-03, -1.92602353e-03,
#          2.65350993e-03,  8.55948959e-04,  4.24074093e-03, -5.49721658e-03]),
#  '더': array([-0.08422513,  0.07647677,  0.07980787, -0.07862279, -0.07761835,
#         -0.08824961,  0.05678207,  0.06374821, -0.04311838, -0.04618904,
#         -0.08252924,  0.07561194,  0.04637601,  0.05299057,  0.03575529,
#         -0.09463085, -0.06683606,  0.09269163,  0.08519432,  0.09648097,
#         -0.09578015, -0.00956005, -0.08324676,  0.05012646, -0.03772187,
#         -0.08708291,  0.09087197,  0.04696754,  0.08778276, -0.07731109,
#          0.06496458,  0.03176592,  0.08749957, -0.08601955, -0.0284953 ,
#         -0.03829863, -0.02814357, -0.04810103,  0.08512915,  0.06465234,
#          0.06934321,  0.06191961, -0.07862666,  0.00487544, -0.09340713,
#         -0.00509233,  0.05832333, -0.05839635, -0.06470032,  0.09882485,
#          0.04657566,  0.06292951,  0.09228063, -0.08020099,  0.07229603,
#          0.00709266, -0.09369248, -0.10462165, -0.04272698, -0.05631344,
#          0.08967388,  0.08058029, -0.09009314,  0.0744902 , -0.00967744,
#          0.07813431,  0.05630102, -0.09125126,  0.04488672,  0.07210016,
#          0.06776392, -0.09158767,  0.04861409,  0.08620479, -0.08572421,
#          0.09800532,  0.10600267, -0.07812111,  0.02369002, -0.05586821,
#          0.05447777, -0.07714039,  0.07115872, -0.05395127,  0.07171506,
#          0.05790082,  0.06651161, -0.06028599, -0.09164389,  0.05426628,
#         -0.02315345, -0.06913984, -0.08984798, -0.01415976,  0.03507251,
#          0.10308384, -0.02921974, -0.04562888, -0.07408871, -0.03746887,
#         -0.07931726, -0.0525757 , -0.0853807 ,  0.07938554,  0.08598262,
#         -0.07205668, -0.07143264,  0.08027509, -0.04373501,  0.05866294,
#         -0.07323646, -0.0316225 , -0.05001424, -0.09701818, -0.07181235,
#         -0.05969271, -0.05531027,  0.00056691,  0.03795231,  0.01917172,
#          0.05880792,  0.06882245,  0.03614915, -0.0407767 , -0.05686868,
#         -0.13272943, -0.0188887 , -0.12193239,  0.06072006, -0.04693901,
#         -0.11930362,  0.13167114,  0.0591874 ,  0.12433418, -0.11392152,
#          0.09508717,  0.03378304,  0.12567112, -0.12500636, -0.03033029,
#         -0.04427483, -0.0321303 , -0.06293438,  0.13108493,  0.0806773 ,
#          0.09466782,  0.08847797, -0.10904779,  0.00877656, -0.13066828,
#         -0.00978665,  0.07571139, -0.07008809, -0.09115271,  0.13928281,
#          0.0593587 ,  0.0825377 ,  0.13617596, -0.1083529 ,  0.10051305,
#          0.00598161, -0.13055635, -0.15322176, -0.05347233, -0.07081554,
#          0.12953339,  0.11784508, -0.12988132,  0.10681724, -0.01339596,
#          0.10897806,  0.073517  , -0.12889329,  0.05543339,  0.10333308,
#          0.09390885, -0.14003121,  0.05686409,  0.11925438, -0.11685182,
#          0.15145648,  0.15226427, -0.10510661,  0.02803296, -0.06391963,
#          0.0791698 , -0.09926848,  0.09323789, -0.07322043,  0.09100023,
#          0.07858947,  0.08756268, -0.08636704, -0.13310522,  0.0646456 ,
#         -0.02767155, -0.08617877, -0.13827603, -0.00833034,  0.03736112,
#          0.14595862, -0.03344493, -0.05837638, -0.10117835, -0.04666808,
#         -0.10987252, -0.06720088, -0.11634396,  0.11753869,  0.1242169 ,
#         -0.0971331 , -0.09687635,  0.1100196 , -0.05370656,  0.06830695,
#         -0.10214141, -0.03424784, -0.06381126, -0.14209455, -0.10657262,
#         -0.07684373, -0.07187294, -0.00295505,  0.04887764,  0.02648817,
#          0.08028585,  0.09605494,  0.04064631, -0.05282516, -0.07133158,
#          0.04182498, -0.13201559,  0.10102378]),
#  '샤를': array([ 3.98837357e-03, -6.10884087e-04, -2.40871784e-03,  3.40561197e-03,
#         -1.12811750e-03, -2.43492999e-04, -1.13549306e-04, -3.11136358e-03,
#         -4.18808836e-04,  1.75494609e-03, -8.49334519e-04, -5.48728300e-03,
#          1.95149621e-03,  2.22855411e-03, -4.27173783e-03, -8.16450713e-04,
#          3.21557102e-03,  7.11760373e-04,  1.08625687e-03, -5.62832467e-03,
#          4.57262450e-03,  3.93169684e-03, -2.81880643e-04,  2.43206985e-03,
#          2.06618484e-03,  1.45242470e-03, -2.74647741e-04, -2.60508630e-03,
#         -1.76038130e-03,  5.08788263e-03, -2.27062500e-03,  2.48096854e-03,
#         -2.70375651e-03, -3.47435041e-04,  1.77966145e-03, -2.06443898e-03,
#          4.23219060e-03, -8.98438598e-05, -6.86853660e-04, -2.85693795e-03,
#         -4.15702153e-03,  2.31954116e-03, -1.30713279e-03,  1.88871090e-04,
#          3.82584301e-03,  2.83936631e-03, -1.12587846e-03,  1.97842689e-03,
#          4.74277544e-03, -2.76714331e-03,  2.08702329e-03, -1.80686499e-03,
#          1.57143328e-03, -1.02720027e-04, -1.59156541e-03, -3.91151765e-03,
#         -9.15131697e-04,  2.41026333e-03,  1.69278789e-03,  8.73902313e-04,
#         -5.52626544e-03, -1.72099732e-03,  3.25140924e-03, -4.86459824e-03,
#         -0.01963712,  0.01694017,  0.00895485,  0.01328178, -0.01664809,
#          0.0127685 ,  0.00317875,  0.01594255, -0.01417462, -0.00337684,
#         -0.01094101, -0.00462682, -0.00969944,  0.01608998,  0.0140999 ,
#          0.01516777,  0.01257144, -0.0170142 ,  0.00167788, -0.01792813,
#         -0.00437444,  0.01522873, -0.01290723, -0.01120643,  0.02164561,
#          0.00995161,  0.01461754,  0.02086653, -0.01610575,  0.01579701,
#          0.00328054, -0.01910374, -0.01729566, -0.00908774, -0.00777156,
#          0.01776429,  0.01568228, -0.01519638,  0.01255312, -0.00435964,
#          0.01483341,  0.01354421, -0.01661229,  0.00924526,  0.01337333,
#          0.01277617, -0.02002044,  0.00691193,  0.01378976, -0.01286059,
#          0.01913748,  0.02114391, -0.0119024 ,  0.00129791, -0.00756337,
#          0.00960602, -0.01665173,  0.01011053, -0.01034303,  0.01649259,
#          0.00922006,  0.00897438, -0.01435656, -0.0148698 ,  0.00637594,
#         -0.00678412, -0.01699388, -0.02096139, -0.00102283,  0.00603331,
#          0.01793911, -0.00750522, -0.00831347, -0.01692326, -0.00438087,
#         -0.01871938, -0.00904722, -0.02025231,  0.01195697,  0.01965435,
#         -0.01632977, -0.01045186,  0.01810648, -0.00916689,  0.01072569,
#         -0.01647477, -0.00590128, -0.00485217, -0.02044168, -0.01838885,
#         -0.00812322, -0.01057767, -0.0015396 ,  0.00797043,  0.00293603,
#          0.00974584,  0.01779425,  0.00987484, -0.01032138, -0.01188616,
#          0.00381595, -0.02204643,  0.01275103]),
#  '전부': array([ 3.33800272e-04,  6.31717977e-04,  2.75711488e-03, -3.79428562e-03,
#         -4.54524471e-03, -8.72200031e-04, -9.06802328e-04,  4.06225178e-03,
#         -4.11593867e-04, -3.30220031e-03, -6.88617499e-03,  6.42718723e-03,
#          2.48090938e-03, -4.75317559e-04,  3.78911575e-03, -7.11546736e-03,
#         -7.03728570e-04,  6.82645864e-03,  2.15599036e-04,  6.47773324e-03,
#         -1.14432361e-03, -2.58936097e-03, -7.15368284e-03,  4.37021777e-03,
#         -4.95017571e-03, -7.23215299e-03,  1.28207789e-03,  3.17889229e-03,
#          2.32698340e-03, -3.86341154e-03,  2.72865190e-03,  4.62673182e-03,
#          1.68776282e-04, -1.89983971e-03, -1.39546927e-03, -2.35352075e-03,
#          1.42271143e-04, -2.26013133e-05,  2.00067273e-03, -1.02788822e-03,
#          4.49592060e-03,  1.43756392e-03, -3.28472275e-03,  2.92150963e-03,
#         -4.82076784e-03, -2.99047905e-04,  6.20283326e-03, -2.02053359e-03,
#         -5.54436382e-03,  4.13367877e-03, -1.39910144e-03,  1.25550616e-03,
#          7.15121878e-03, -9.49351369e-04,  6.05032946e-03,  3.89078930e-03,
#         -4.26190722e-03, -6.10986012e-03, -1.08823767e-03, -2.66128478e-04,
#          2.90888178e-03,  4.78392638e-03, -5.57859520e-04,  1.85680170e-03,
#         -2.99778906e-03,  1.78384838e-03,  4.34260132e-03, -2.96347628e-03,
#          2.56590349e-03,  1.16047232e-03,  4.25404360e-03, -1.48872113e-03,
#         -7.33223416e-04,  6.20610852e-03, -4.92849865e-03,  2.15171216e-03,
#          5.39449122e-03, -2.03579461e-03, -1.22718579e-03, -4.87520403e-03,
#          5.36417075e-03, -2.63306223e-03,  5.35500108e-03, -4.59638111e-03,
#          4.29933476e-03, -9.45032651e-04,  5.71330444e-03, -5.48165794e-03,
#         -1.87665131e-03, -5.82401321e-04,  1.68892669e-03, -2.95904150e-03,
#         -3.15306901e-03, -4.43378113e-03,  5.27523027e-03,  7.37413938e-03,
#          1.45252340e-03, -4.09868237e-03, -1.98819193e-03, -2.28243677e-03,
#         -6.75860811e-03, -5.38369344e-03, -4.43559296e-03,  7.19072692e-03,
#          1.14007731e-03, -1.94311007e-03, -3.18735405e-03,  3.08864448e-03,
#         -5.48533577e-04,  5.17786492e-03, -1.68369888e-03, -3.07070553e-03,
#         -4.15635063e-03, -3.98644522e-03, -1.36441962e-03, -1.18016889e-03,
#         -4.54509283e-03,  5.15233302e-04,  1.58670587e-03,  2.72566283e-04,
#          8.69447995e-04,  1.20279282e-03,  5.14977290e-03, -4.89579373e-03,
#         -4.28530130e-03,  4.71328188e-03, -1.86036697e-03,  6.99518048e-03]),
#  '다': array([-0.16056629,  0.15375051,  0.15965566, -0.15133804, -0.15589779,
#         -0.17510149,  0.11781462,  0.12678404, -0.10668167, -0.1031119 ,
#         -0.1690643 ,  0.15097748,  0.0946107 ,  0.10987366,  0.08243513,
#         -0.17533127, -0.13576724,  0.17824369,  0.172811  ,  0.17676965,
#         -0.17815077, -0.02622994, -0.16680781,  0.10673717, -0.0790636 ,
#         -0.16589015,  0.16853439,  0.09576521,  0.16676015, -0.16103933,
#          0.14308852,  0.06782255,  0.16937807, -0.16597695, -0.05435519,
#         -0.08607946, -0.06101103, -0.11344096,  0.16902891,  0.12655117,
#          0.14677821,  0.13698809, -0.15752734,  0.0148786 , -0.17663235,
#         -0.01374782,  0.12902009, -0.12016657, -0.13891991,  0.17877447,
#          0.09811742,  0.12725607,  0.17407248, -0.15929436,  0.14666023,
#          0.01610901, -0.17116795, -0.19281831, -0.08817145, -0.1166613 ,
#          0.17293213,  0.16343692, -0.17700535,  0.1536953 , -0.02998192,
#          0.1527154 ,  0.12424577, -0.17267545,  0.0926869 ,  0.15130976,
#          0.13998394, -0.18404179,  0.09939712,  0.16125928, -0.15889814,
#          0.18937454,  0.1973972 , -0.15683777,  0.05499923, -0.11263014,
#          0.12622032, -0.15141016,  0.13781562, -0.12862369,  0.14018331,
#          0.12296441,  0.13725721, -0.13321747, -0.17720145,  0.1114975 ,
#         -0.05133552, -0.13872936, -0.1776306 , -0.02644557,  0.0749777 ,
#          0.19101362, -0.06304883, -0.10339598, -0.14330739, -0.08601622,
#         -0.15638149, -0.11059352, -0.16388252,  0.1611772 ,  0.1704805 ,
#         -0.1448202 , -0.13996731,  0.15250862, -0.09867127,  0.11361695,
#         -0.15060981, -0.07480084, -0.10427376, -0.17848043, -0.1462415 ,
#         -0.12253405, -0.11715001, -0.00513777,  0.09225891,  0.05233059,
#          0.12928128,  0.14875805,  0.08388069, -0.09735945, -0.12018599,
#          7.81782226e-04, -4.40586018e-04,  1.26686115e-03,  2.61127774e-03,
#          2.50041986e-05, -1.56028538e-03,  7.90828373e-04, -1.52274052e-03,
#         -4.36386297e-03,  2.22328416e-03,  2.85071738e-03, -1.90969965e-03,
#         -1.89954834e-03, -3.42501216e-03,  3.67198227e-04, -2.62589211e-03,
#          2.40659579e-03, -2.38549516e-03, -3.64174752e-03,  2.57182780e-03]),
#  ...}

# %%
word_dict.keys()
# Out:
# dict_keys(['현재', '호텔', '주인', '심정', '아', '18', '난', '마른하늘', '에', '날벼락', '맞고', '망하게', '생겼는데', '누', '군', '계속', '추모', '받네', '못', '된', '넘', '들', '남', '의', '고통', '을', '즐겼던', '들이', '젠', '마땅한', '처벌', '받아야지', '그', '래야', '공정한', '사회', '지', '심은대로', '거두거라', '1', '사람', '얼굴', '손톱', '으로', '긁은것은', '인격', '살해', '이고', '2', '동영상', '이', '몰카', '냐', '메걸', '리안', '생각', '없노', '100년', '안에', '남녀', '간', '성', '전쟁', '한번', '크게', '치룬', '후', '일부다처제', '여성', '정치', '참여', '금지', '투표', '권', '삭제', '가', '세계', '공통', '문화', '로', '자리', '잡을듯', '암탉', '너무', '울어', '댐', '180', '이하', '호빗', '한남', '은', '결혼', '하지마', '셈', 'ㅋ', '돈', '없으면', '연애', '도', '니', '유전자', '받아서', '받을', '네', '후손', '뭔', '죄임', '키', '감량', '을해', '야', '박수', '쳐주지', '그냥', '먹고', '싶은거다', '먹고디', '비져', '자고', '하', '면', '로는', '쪄', '230', '대', '골빈', '여자', '기사', '다', '모이는', '건가', 'ㅋㅋㅋㅋ', '이래서', '는', '주면', '안된다', '엠넷', '사전투표', '나', '하고', '살아야지', '계집', '2006년', '포도', '밭', '사나이', '에서', '흰가운', '입은', '연구원', '정소영', '봐라', '솔', '까', '대한민국', '여배우', '중', '최고', '이쁘고', '단아', '했다', '급식', '충', '멋', '모르고', '윤아', '아이유', '떠들겠지만', '20', '30', '남자', '비율', '보소', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '할', '짓', '드럽게', '없나', '봐', '죽자고', '덤벼', '드는거', 'ㅠㅠ', '29', '살', '까지', '온갖', '수단', '동원', '해서', '입대', '연기', '하며', '발악', '하다가', '어쩔', '수없이', '끌려가는게', '머', '대단하다고', '오', '바질', '이야', 'ㅋㅋ', '녀', '쿵쾅', '꿀꿀', '꿀', '박', '2일', '뭐', '기레기', '가장', '높은거', '보니', '고소영', '이뻐요', '하는', '이유', '를', '알겠다', '진심', '한마디', '하겠는데', '아예', '안보', '여요', '33', '살이', '청년', '임', '아저씨', '아님', '38', '되도록', '시집', '갔으면', '뭔가', '문제', '있는', '아닌가', '건', '모형', '거르세', '요', '상대', '필요', '없어요', '4050', '대로', '가야', '매', '부르면', '우', '야노', '40', '아줌마', '자식', '피', '씨방', '있고', '엄마', '방탄', '처', '보고', '있다고', '해봐라', '그래놓고', '경포대', '문재인', '몰랑', '지지', '어후', '토나와', '나이', '값못', '현빈', '멋있다고', '하악하악', '거리', '거', '개극혐', '당신', '튀어나온', '뱃살', '과', '흉측한', '반성', '하길', '바람', '늙은이', '32', '돌아이련', '쯧쯧', '쯧', '폐경', '다리', '노답', '라이', 'ㅋㅋㅋ', '세', '이상', '한', '임신', '사실', '상', '쓸모없는', '분리수거', '대상', '52', '퍼', '되는', '강한나', '테러', '하네', '만', '하세요', '님들', '추해', '보임', '82', '키로', '김지영', '왜', '보냐', '저런', '쓰레기', '영화', '안', '봄', '팬', '죽일', '정도', '극성', '였다든', '데', '좌빨', '방송', '인데', '문', '재앙', '좋아하나', '운동', '무슨', '얼어', '죽', '마녀사냥', '이지', '항해', '야함', '필요없다', '조개', '갖고', '개', 'ㅈㄹ', '태콩', '이나', '촐싹대는', '조', '샌', '징', 'ㅈㄴ', '웃김', '모임', '이네', '뉴스', '1분', '나오는', '뒷방', '3', '류', '나라', '잃을것도', '업시', '친', '좌파', '방송국', '설립', '려고', '퇴사', '쌉', '친아나', '와', '꾸만', '번', '지르하고', '속', '맘충', '과동', '급', '소신', '지키고', '나로', '서', '소명', '다한', '배현진', '새삼', '이쁘다', '옆', '에는', '침', '흘리면서', '있다는걸', '모르는', '뇬', '있네', '무조건', '혐오', '증', '걸리지말고', '연예인', '인기', '인', '라면', '빤쯔흘리는뇬들', '얼마나', '많은지', '모르나', '아닌가요', '이제', '같은', '한국', '법', '이라는', '승리', '놈', '클럽', '어쩌', '고', '관련', '잇던', '애', '아니', '엇', '그런데', '얼쩡거리고', '드나들던', '연예계', '가에서', '퇴', '출하', '인물', '리도', '없어', '내', '추천', '좀', '해주까', '걸그룹', '가치', '있음', '요즘', '아이돌', '넘어도', '늙은거', '아이즈', '원', '장원영', '안유진', '유나', '같', '은애', '17', '니까', '존나', '쩔지', '어린게', '개돼지', '있어서', '개한민국', '엉망', '진창', '인거야', '주제', '알아야지', '일베충', '만큼', '베충', '말아먹는', '일반', '인들', '섭외', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '심', '몽', '욕', '하면서', '약', '쟁이', '칭찬', '하냐', '반칙', '딴', '메달', '정당성', '휴', '의욕', '없고', '빨러에', '핑계', '대기', '일상', '전세계', '아니고', '선진국', '비비면서', '임금', '거론', '하는게', '어이없다', '안마', '제이', '튠', '주식', '먹튀', 'ㅆㄹㄱ', '노무현', '하지', '않은게', '다행', '속보', 'ㅈ', '됐다', '국민', '가수', '조용필', '빨갱이', '마', '저', '고향이', '으', '전라도', '아이', '라', '카이', '윤', '총경', '동향', '서로', '술', '골프', '외', '운영', '술집', '영업정지', '봐주고', '태어나지', '말고', '분리', '되어야', '절', '라도', 'ㄴ', 'ㅁㅊ', '슬슬', '기어', '나오시구요', 'ㅅㅂ', '더럽게', '메', '갈어로', '제목', '뽑는거', '저런거지', '알', '저랬겠냐', '꼰대', '새', '말', '많네', 'ㅅㅅ', '게', '자랑', 'ㅈㅅ', '그것', '언제', '하셨나요', '무시', '하셔요', '우리', '팜므파탈', '나래', '씨', 'ㅆ', '성과', '비교', '안되는', '자연미', '좋다거의', '이영애', '배우', '미모', 'ㅇㄴ', '씨뱅', '마약', '것', '성추행', '아닌데', '무안줫다', '존', 'ㄹㅏㄹ', 'ㅋㅋㅋㅋㅋㅋㅋ', '감히', '생글', '않았다고', '헤드라인', '비꼬기', '시전', 'ㅇㅣ', '아즘마', '조용히', '싶다면서', '자꾸', '기어나와', '많이', '벌었다고', '예능', '깝치더', '관종임', 'ㅇ', '정보', '부', '사하나', '봐요', '곧', '자살', '하겠네', '경찰', '질소', '넣고', '했다고', '라인', '병들', '사기', '치던', '절도', '하던', '깜방', '있어 ...

# %%
'''
#새로운 테스트 데이터 임베딩 시
# word dict : train데이터의 임베딩 사전
total_word_dict = {}
cnt = 0

for word in test_token:
    if word in word_dict.keys():
        total_word_dict[word] = word_dict[word]
    else:
        word_dict[word] = np.zeros((128))
        cnt += 1  # 처음 본 단어 갯수 세기

print('no train word -> 0....', cnt)
print('token -> word embedding....!',len(unique_tokens))
'''
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-6267fdb67d4a> in <module>
#       5
#       6 for word in test_token:
# ----> 7     if word in word_dict.keys():
#       8         total_word_dict[word] = word_dict[word]
#       9     else:
#
# TypeError: unhashable type: 'list'

# %%
test_token = train_token

def sent2vec_glove(tokens, embedding_dim=128):
    #문장 token 리스트를 받아서 임베딩 시킨다
  
    size = len(tokens)
    matrix = np.zeros((size, embedding_dim))
    word_table = word_dict     # glove word_dict

    for i, token in enumerate(tokens):
        vector = np.array([
            word_table[t] for t in token
            if t in word_table
        ])

        if vector.size != 0:
            final_vector = np.mean(vector, axis=0)
            matrix[i] = final_vector

    return matrix


#문장 임베딩
sentence_glove = sent2vec_glove(test_token)
sentence_glove.shape
# Out:
# (5312, 128)

# %%
# sklearn
from sklearn.cluster import DBSCAN
from sklearn.manifold import TSNE
# 시각화
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# clustering
dbscan = DBSCAN(eps=0.5)
#k = 20
#kmeans = KMeans(n_clusters=k, random_state=2021).fit(sentence_glove)
#y_pred = kmeans.fit_predict(sentence_glove)
#y_pred = kmeans.labels_
y_pred = dbscan.fit_predict(sentence_glove)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
len(y_pred)
# Out:
# 5664

# %%
# tsne
tsne = TSNE(verbose=1, perplexity=100, random_state=2021)   # perplexity : 유사정도
X_embedded = tsne.fit_transform(sentence_glove)
print('Embedding shape 확인', X_embedded.shape)
# Out:
# [t-SNE] Computing 301 nearest neighbors...
# [t-SNE] Indexed 5312 samples in 0.297s...
# [t-SNE] Computed neighbors for 5312 samples in 3.830s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5312
# [t-SNE] Computed conditional probabilities for sample 2000 / 5312
# [t-SNE] Computed conditional probabilities for sample 3000 / 5312
# [t-SNE] Computed conditional probabilities for sample 4000 / 5312
# [t-SNE] Computed conditional probabilities for sample 5000 / 5312
# [t-SNE] Computed conditional probabilities for sample 5312 / 5312
# [t-SNE] Mean sigma: 0.009868
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 52.664665
# [t-SNE] KL divergence after 1000 iterations: 0.424113
# Embedding shape 확인 (5312, 2)

# %%
#X_embedded
# Out:
# array([[-19.179502, -14.616597],
#        [-40.24852 , -16.819965],
#        [ 23.618862, -33.55902 ],
#        ...,
#        [ 35.24004 , -12.766662],
#        [ 19.38374 , -37.438507],
#        [ 33.65274 , -14.60445 ]], dtype=float32)

# %%
tsne = pd.DataFrame(X_embedded)
#tsne.to_csv('mbig_glove_tsne.csv',encoding='utf-8-sig')
#tsne = pd.read_csv('mbig_glove_tsne.csv',index_col=0)
tsne
# Out:
#               0          1
# 0    -19.179502 -14.616597
# 1    -40.248520 -16.819965
# 2     23.618862 -33.559021
# 3     13.738192  39.750477
# 4     12.448126  40.825871
# ...         ...        ...
# 5307  19.913496 -36.687073
# 5308  34.126202  -7.058076
# 5309  35.240040 -12.766662
# 5310  19.383739 -37.438507
# 5311  33.652740 -14.604450
#
# [5312 rows x 2 columns]

# %%
sns.set(rc={'figure.figsize':(20,20)})
# colors
#palette = sns.hls_palette(10, l=.4, s=.9) 
#palette = sns.color_palette('CMRmap_r',2)
# plot
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=y_pred,
                legend='full',s=30,palette='CMRmap_r')

plt.title('t-SNE with DBSCAN Labels and Glove Embedding')
plt.savefig('glove_tsne_dbscan.png')
plt.show()

#plt.scatter(X_embedded[:,0], X_embedded[:,1],hue=y_pred,style=y_pred,s=5)
#plt.colorbar(shrink=0.7)
# Out:
# C:\Users\JAIEUN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# 시각화
sns.set(rc={'figure.figsize':(20,20)})
# colors
#palette = sns.hls_palette(10, l=.4, s=.9) 
palette = sns.color_palette('CMRmap_r',20)
# plot
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=y_pred,
                legend='full',palette=palette)     # kmeans로 예측

plt.title('t-SNE with KMeans Labels and Glove Embedding')
plt.savefig('tsne_glove_embedding_all.png')
plt.show()
# Out:
# C:\Users\JAIEUN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data['cluster'] = y_pred
data
# Out:
#                                                 comment  sentiment  cluster
# 0     이 거 그거 같다 그 분노의 질주 더 익스트림에서 샤를리즈 테론 사이퍼 이 좀비 타...        0.0       11
# 1                           아니 ㅋㅋ 브레이크 등 왜 안 들어오냐고 아 ㅋㅋ        0.0       16
# 2     볼보운전자보다 제가 운전 경력 삼십년 가까이 됩니다그동안 대우차 현대차 쉐보레 차 ...        0.0        3
# 3                                         주차부터 멋지게 하셨네요        0.0       13
# 4                              운전 실력 굳 국기 게양대 파워 클라스 인정        0.0       13
# ...                                                 ...        ...      ...
# 5659                           최명숙 딱 봐도 님이 잼민이 같아 요 능지가        1.0       14
# 5660        최명숙 아니 행동하고 생각하는 게 잼민이 같다는 거에 요 이해력이 부족하신 듯        1.0       16
# 5661                                       잼민이 아니죠 어륜이죠        1.0        5
# 5662                         누가 문재인 얼굴에다 계란 좀 던져줬으면 좋겠다        1.0       13
# 5663                                               지랄ㅋㅋ        1.0        5
#
# [5664 rows x 3 columns]

# %%
data.to_csv('glove_kmeans20_w20.csv',encoding='utf-8-sig')

# %%
print(data['comment'][data['cluster']==1]) #531개
print()
print(data['comment'][data['cluster']==2])
print()
print(data['comment'][data['cluster']==3])
print()
print(data['comment'][data['cluster']==4])
# Out:
# 2       볼보운전자보다 제가 운전 경력 삼십년 가까이 됩니다그동안 대우차 현대차 쉐보레 차 ...
# 6                                               저기 우리 동넨데
# 8       수동 타는 데 현기차 고 수입차고 쌍용차 고 급발진 사고가 일어 나네요 너무 무섭다...
# 14                              키 햐급발진 나면 고객 탓 국내나 국외나 ㅋㅋ
# 15                   전기차를 타면 4226226 이렇게 될 수 있는 거니까 어떻게 탐
#                               ...
# 5631                           ㅈ 까세요 말로 해서 안 되는 일도 있는 법이여
# 5633                                             문쪼잔뱅이는 쩝
# 5638                                           거지 같은 유튜버들
# 5646                            저 때 닭년 목아지를 비틀어버렸어야 되는 건데
# 5656                              어그로 장인 틀 딱 아 한글 교실 좀 가라
# Name: comment, Length: 531, dtype: object
#
# 4       운전 실력 굳 국기 게양대 파워 클라스 인정
# 13                         2억 겨우
# 26             엄청나게 와 소름 무섭네요 ㅜㅜ
# 40                         중국산 끝
# 69                          무섭네요
#                   ...
# 5586                        ㅁㅊㅅㄲ
# 5603                     역시 똥 싼고
# 5614                           ㅗ
# 5649                   시발 이해해버렸다
# 5652         저걸 확 그냥 때릴 수도 없고 스벌
# Name: comment, Length: 306, dtype: object
#
# 20                          브레이크 등이 안 들어오는데 아닌가
# 74                             브레이크 등이 안 들어오는 데
# 141                          브레이크 등은 왜 안 들어왔을까요
# 143                              브레이크 등이 안 들어온다
# 234                  저들이 축제라 하고 즐기는 사람이 있으면 축제다
#                          ...
# 5482                           저런 미친 감독이 한 둘이겠나
# 5516                            쓰레기들이 많아도 너무 많다
# 5535    이런 것들이 있으니까 유망주들이 도 중 하차를 하는 거지 돈벌레 새끼들
# 5543            제도가 뒷받침 안 되니 저런 쓰레기 감독들이 나오는 거다
# 5609                        아직도 이런 쓰레기들이 있다니 ㅠㅠ
# Name: comment, Length: 96, dtype: object
#
# 0       이 거 그거 같다 그 분노의 질주 더 익스트림에서 샤를리즈 테론 사이퍼 이 좀비 타...
# 9       3달 된 사고를 지금 엠빅이 올린 다이건 운전자가 언론 플레이 하려는 거임 이 거 ...
# 23                                     공포의 19초 영상은 4분 26초
# 48                        이 사고 역시 운전자 과실로 몰아가겠죠 늘 그랬던 것처럼
# 49                           근데 브레이크는 왜 안 잡냐 운전 미숙 90퍼 이상
#                               ...
# 5627    좀 바꼈으면 한 다 늙다리들이 한 자리 꿰차면 놔줄 생각을 안하네 그러다 벌받아서 ...
# 5639                                        똥이나 처 먹어 이 들아
# 5651                                        문재앙도 안 맞음 공통점
# 5655                                       맞습니다 국개들 매가 약임
# 5658                         최명숙님이 어른 패륜 합쳐서 어륜한 거 같은데 ㅋㅋ
# Name: comment, Length: 597, dtype: object

# %%
print(data['comment'][(data['sentiment']==0)&(data['cluster']==1)])
print()
print(data['comment'][(data['sentiment']==1)&(data['cluster']==1)])
# Out:
# 2       볼보운전자보다 제가 운전 경력 삼십년 가까이 됩니다그동안 대우차 현대차 쉐보레 차 ...
# 6                                               저기 우리 동넨데
# 8       수동 타는 데 현기차 고 수입차고 쌍용차 고 급발진 사고가 일어 나네요 너무 무섭다...
# 14                              키 햐급발진 나면 고객 탓 국내나 국외나 ㅋㅋ
# 15                   전기차를 타면 4226226 이렇게 될 수 있는 거니까 어떻게 탐
#                               ...
# 2498     아니 못 배워 먹은 티를 꼭 나이 먹어서도 내야겠어 진짜 너무 하네 지도자가 맞는지 참
# 2590                                             왜 이러는 걸까
# 2601                                말로 해서 안 되니 계란 던지지 않을까
# 2603                아무리 정치인이 싫어도 칼로 얼굴 긁는 건 아니다 명백한 살인미수다
# 2648                바로 고소당하고 국정 윈 지하실로 끌려가서 온갖 고문은 다 당할 듯
# Name: comment, Length: 267, dtype: object
#
# 2654                        안 전 따지지 말고 결함을 따져라 똥대가리 색히 들아
# 2662                                       와 근데 운전 ㅈㄴ 잘하네
# 2670    아이고 현대 기 아가 그러니깐 보란 듯이 차주한테 떠넘기네 나라꼬라지가 븅신같이 돌...
# 2671                                  ㅋㅋㅋㅋㅋㅋ 2억배상은 뭐야 미친년
# 2675    왜 항상 급발진은 거의 고령자 여성 운전자일까 그게 너무 궁금하다 젊은 남성 운전자...
#                               ...
# 5631                           ㅈ 까세요 말로 해서 안 되는 일도 있는 법이여
# 5633                                             문쪼잔뱅이는 쩝
# 5638                                           거지 같은 유튜버들
# 5646                            저 때 닭년 목아지를 비틀어버렸어야 되는 건데
# 5656                              어그로 장인 틀 딱 아 한글 교실 좀 가라
# Name: comment, Length: 264, dtype: object

# %%
# 최적의 K 찾기 : 군집 갯수 k 찾기
from sklearn import metrics
from scipy.spatial.distance import cdist

# K=50 개의 클러스터에 대해서 시각화
distortions = []
K = range(2, 50)
#tqdm.pandas()

for k in K:
    k_means = KMeans(n_clusters=k, random_state=42).fit(sentence_glove)
    k_means.fit(sentence_glove)
    distortions.append(sum(np.min(cdist(sentence_glove, k_means.cluster_centers_, 'euclidean'), axis=1)) / sentence_glove.shape[0])
    
    print('Found distortion for {} clusters'.format(k))

# Visualization
X_line = [K[0], K[-1]]
Y_line = [distortions[0], distortions[-1]]

# Plot the elbow
plt.plot(K, distortions, 'b-')
plt.plot(X_line, Y_line, 'r')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('Optimal K')
plt.show()
# Out:
# Found distortion for 2 clusters
# Found distortion for 3 clusters
# Found distortion for 4 clusters
# Found distortion for 5 clusters
# Found distortion for 6 clusters
# Found distortion for 7 clusters
# Found distortion for 8 clusters
# Found distortion for 9 clusters
# Found distortion for 10 clusters
# Found distortion for 11 clusters
# Found distortion for 12 clusters
# Found distortion for 13 clusters
# Found distortion for 14 clusters
# Found distortion for 15 clusters
# Found distortion for 16 clusters
# Found distortion for 17 clusters
# Found distortion for 18 clusters
# Found distortion for 19 clusters
# Found distortion for 20 clusters
# Found distortion for 21 clusters
# Found distortion for 22 clusters
# Found distortion for 23 clusters
# Found distortion for 24 clusters
# Found distortion for 25 clusters
# Found distortion for 26 clusters
# Found distortion for 27 clusters
# Found distortion for 28 clusters
# Found distortion for 29 clusters
# Found distortion for 30 clusters
# Found distortion for 31 clusters
# Found distortion for 32 clusters
# Found distortion for 33 clusters
# Found distortion for 34 clusters
# Found distortion for 35 clusters
# Found distortion for 36 clusters
# Found distortion for 37 clusters
# Found distortion for 38 clusters
# Found distortion for 39 clusters
# Found distortion for 40 clusters
# Found distortion for 41 clusters
# Found distortion for 42 clusters
# Found distortion for 43 clusters
# Found distortion for 44 clusters
# Found distortion for 45 clusters
# Found distortion for 46 clusters
# Found distortion for 47 clusters
# Found distortion for 48 clusters
# Found distortion for 49 clusters
